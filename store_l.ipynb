# %% [markdown]
# # Defining Hubs Location Based on the Store Location

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import requests
import json
import time
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import matplotlib.cm as cm
import matplotlib.colors as colors

import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# ## Use Google Maps API Text Search to get all stores in Manhattan

# %%
shops = []
# possible keywords (based on supported types: https://developers.google.com/maps/documentation/places/web-service/supported_types)
keyw = ['store', 'shop', 'supermarket', 'market', 'restaurant', 'diner', 'fashion', 'boutique', 'drugstore', 'bakery', 'book_store', 'coffee%20shop', 'cafe', 'clothing%20store', 'market', 'market%20place', 'food', 'food%20farm', 'grocery_or_supermarket','bicycle_store', 'convenience_store','electronics_store','florist','hardware_store','home_goods_store','pet_store','shoe_store']

# loop through all possible keywords
for i in keyw:
    params = {}
    #limitation through keywords in the query (... manhattan) and radius (10200 m from the center of Manhattan)
    # define query and get data from Google API
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={i}%20manhattan&location=40.7830603,-73.9712488&radius=10200&region=US&key=AIzaSyBEindiZbV6koN4ycLksmKt4wBkmxwUoAU"

    # save query results in json file
    res = requests.get(url, params = params)
    results = json.loads(res.content)

    # extend array
    shops.extend(results['results'])

    # go through all individual results in while-loop
    while "next_page_token" in results:
         params['pagetoken'] = results['next_page_token'],
         res = requests.get(url, params = params)
         results = json.loads(res.content)
         shops.extend(results['results'])

    #payload={}
    #headers = {}

    #display results directly
    #response = requests.request("GET", url, headers=headers, data=payload)

#output
#print(response.text)

# %%
shops
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '629 6th Ave, New York, NY 10011',
#   'geometry': {'location': {'lat': 40.7403433, 'lng': -73.994933},
#    'viewport': {'northeast': {'lat': 40.74164222989272,
#      'lng': -73.99347882010728},
#     'southwest': {'lat': 40.73894257010728, 'lng': -73.99617847989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The Container Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2992,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110760471164144229254">Pichsinee Uansiri</a>'],
#     'photo_reference': 'Aap_uEA9-AWgVMtHvOr0pgqdBnv8oB-lepbUqY6PcBwR22YGugLzkJoMIODyI3-Njg48qHnM8-M9Eqs_laEK0XCjR-QvuGYb3FjryIjji-vWr2SR5ECMfCrgZo4AEMaQDoasAz-Y8yvZpkoCUjAOpKok9qyQoXVlSYkB5spUBLNKVoKU0EWk',
#     'width': 5312}],
#   'place_id': 'ChIJlzpEM6NZwokRHEmZ4wh60aI',
#   'plus_code': {'compound_code': 'P2R4+42 New York',
#    'global_code': '87G8P2R4+42'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJlzpEM6NZwokRHEmZ4wh60aI',
#   'types': ['home_goods_store',
#    'furniture_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1279},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '334 Lexington Ave, New York, NY 10016',
#   'geometry': {'location': {'lat': 40.7497237, 'lng': -73.9775697},
#    'viewport': {'northeast': {'lat': 40.75102222989272,
#      'lng': -73.97625762010729},
#     'southwest': {'lat': 40.74832257010728, 'lng': -73.97895727989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Small Shop and Stop',
#   'permanently_closed': True,
#   'place_id': 'ChIJf3hmUQFZwokRI2WfbWaIJ0A',
#   'plus_code': {'compound_code': 'P2XC+VX New York',
#    'global_code': '87G8P2XC+VX'},
#   'rating': 0,
#   'reference': 'ChIJf3hmUQFZwokRI2WfbWaIJ0A',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '115 W 25th St, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.7445994, 'lng': -73.99258929999999},
#    'viewport': {'northeast': {'lat': 40.74590967989272,
#      'lng': -73.99126847010729},
#     'southwest': {'lat': 40.74321002010728, 'lng': -73.99396812989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Thrift Shop in Manhattan',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJufARCUFZwokRVCTcUT7YFhs',
#   'plus_code': {'compound_code': 'P2V4+RX New York',
#    'global_code': '87G8P2V4+RX'},
#   'rating': 4,
#   'reference': 'ChIJufARCUFZwokRVCTcUT7YFhs',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '235 W 46th St, New York, NY 10036',
#   'geometry': {'location': {'lat': 40.7596202, 'lng': -73.98720689999999},
#    'viewport': {'northeast': {'lat': 40.76089482989272,
#      'lng': -73.98580542010727},
#     'southwest': {'lat': 40.75819517010728, 'lng': -73.98850507989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Hamilton: The Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101738755731412055343">Matt Bohmfalk</a>'],
#     'photo_reference': 'Aap_uEB-_8Zh2Aw71D4k-kJGqIc2_DH9MnzPc-piSQ13gKllkyCFkjyP84GI13NN-0IG4ItIP3ORALoDBL_ojIMDLAOPeAgXXQU7MeqbbaGI61Lpssay13fVe_wNtfS3qDlTKvL33Xf4C583x3LQwAhZBBumSJZe8meF3_HwIGTiW5P_Q4S9',
#     'width': 4048}],
#   'place_id': 'ChIJX7ruPlRYwokRtPrnnFkQClQ',
#   'plus_code': {'compound_code': 'Q257+R4 New York',
#    'global_code': '87G8Q257+R4'},
#   'rating': 4.4,
#   'reference': 'ChIJX7ruPlRYwokRtPrnnFkQClQ',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 73},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1848 2nd Ave, New York, NY 10128',
#   'geometry': {'location': {'lat': 40.7838073, 'lng': -73.94707249999999},
#    'viewport': {'northeast': {'lat': 40.78522192989272,
#      'lng': -73.94586607010729},
#     'southwest': {'lat': 40.78252227010728, 'lng': -73.94856572989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet',
#   'name': 'F&A Discount Store',
#   'place_id': 'ChIJERgMok1ZwokRvqpg7_ou5d4',
#   'plus_code': {'compound_code': 'Q3M3+G5 New York',
#    'global_code': '87G8Q3M3+G5'},
#   'rating': 5,
#   'reference': 'ChIJERgMok1ZwokRvqpg7_ou5d4',
#   'types': ['convenience_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 2},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '112 W 34th St, New York, NY 10120',
#   'geometry': {'location': {'lat': 40.7498313, 'lng': -73.9887048},
#    'viewport': {'northeast': {'lat': 40.75118112989272,
#      'lng': -73.98735497010726},
#     'southwest': {'lat': 40.74848147010727, 'lng': -73.99005462989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Target',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103579957491410786911">Jolene Stahn</a>'],
#     'photo_reference': 'Aap_uEAmwVQTdXOQQioq8YofEHeDGBK2EGZ49Y7xfFvDVDenMLy-TFjRQDHVoAGlUbK9Td85Vtv2ML5IEYKUxXfq1hp-rcKb9W-rBBPmmqRhlXJi4n7wI8UDAxBrOhkihWpGjBrKqgzCQwFpx2pH-cCqwgmEjg7BSTp3uHVKNuPw8FogK6hw',
#     'width': 3024}],
#   'place_id': 'ChIJsdA-sa5ZwokRPNShF3C2zas',
#   'plus_code': {'compound_code': 'P2X6+WG New York',
#    'global_code': '87G8P2X6+WG'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJsdA-sa5ZwokRPNShF3C2zas',
#   'types': ['department_store',
#    'electronics_store',
#    'furniture_store',
#    'home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 716},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1333 Broadway Herald Sq, NY 10018',
#   'geometry': {'location': {'lat': 40.7508858, 'lng': -73.9879741},
#    'viewport': {'northeast': {'lat': 40.75218052989272,
#      'lng': -73.98663632010727},
#     'southwest': {'lat': 40.74948087010728, 'lng': -73.98933597989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Urban Outfitters',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116507382416807671621">mamrak s</a>'],
#     'photo_reference': 'Aap_uEAKWn7MdHQIUwd2cBbpavvXQNS2ZfgM6hsHHAoGvIC_c4cxKPKxf6QWRgoc0cgfZKLuJRAzLyB-uMvNhJac7ee_N9YkvfXrmJzAh54gTux4XwGVFNWP_zEJ24m_-qpJKhJFQPkU16yfkV59yEfdF8ihnbl5wemlAedsBtQVyo5p5jCo',
#     'width': 4032}],
#   'place_id': 'ChIJpaBx5KtZwokRhEtgddx5-XI',
#   'plus_code': {'compound_code': 'Q226+9R New York',
#    'global_code': '87G8Q226+9R'},
#   'price_level': 3,
#   'rating': 4.2,
#   'reference': 'ChIJpaBx5KtZwokRhEtgddx5-XI',
#   'types': ['clothing_store',
#    'shoe_store',
#    'electronics_store',
#    'home_goods_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1617},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '245 W 29th St 8th floor, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.74882059999999, 'lng': -73.9945268},
#    'viewport': {'northeast': {'lat': 40.75006302989272,
#      'lng': -73.99325577010728},
#     'southwest': {'lat': 40.74736337010728, 'lng': -73.99595542989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Manhattan Wardrobe Supply',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108265499063981766028">M K</a>'],
#     'photo_reference': 'Aap_uEA_bS-NmAVNm_mCzFiP2uPbLgHOLTzl23eDAO-FCSVD5RnaX_N1w8e6qqeOP5vdoj8esTVrVxOfb9TORiGanYidjnczMss3OfjUSR9xmtuwjjSxq7F4jXYQqcBtxEmmeaYecvj59DqZGn7rR_EMU5OpMF59HUzKPYPM-ws8E-S8kpOG',
#     'width': 4032}],
#   'place_id': 'ChIJmc6MJ7BZwokRNVnUt90Aw78',
#   'plus_code': {'compound_code': 'P2X4+G5 New York',
#    'global_code': '87G8P2X4+G5'},
#   'rating': 4.7,
#   'reference': 'ChIJmc6MJ7BZwokRNVnUt90Aw78',
#   'types': ['department_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 210},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '248 E 44th St, New York, NY 10017',
#   'geometry': {'location': {'lat': 40.7511748, 'lng': -73.97168769999999},
#    'viewport': {'northeast': {'lat': 40.75252462989273,
#      'lng': -73.97033787010727},
#     'southwest': {'lat': 40.74982497010729, 'lng': -73.97303752989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet',
#   'name': 'M&A Variety Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105170431124683218627">Marc Gonzalez</a>'],
#     'photo_reference': 'Aap_uECVskpksRfIemqmg5XSGcfCgbrQTrvHs9BjWcD04VvEGQtL8OTOnoWKb6ihQfxHfQSnmPX6cFbf9kqlwhR46HiNQUD1LXHLI5jQ1BCaHJKeuxH2qf1jWOmm053HrT_gWE7Nx_RNWa2BtDg_MT4dUzvI3bElW7wxN2dKeijhwyX9_1A7',
#     'width': 3021}],
#   'place_id': 'ChIJT_1h1gJZwokRRrVRnAEWMVc',
#   'plus_code': {'compound_code': 'Q22H+F8 New York',
#    'global_code': '87G8Q22H+F8'},
#   'rating': 5,
#   'reference': 'ChIJT_1h1gJZwokRRrVRnAEWMVc',
#   'types': ['convenience_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1515 Broadway, New York, NY 10036',
#   'geometry': {'location': {'lat': 40.7578341, 'lng': -73.9858859},
#    'viewport': {'northeast': {'lat': 40.75905862989271,
#      'lng': -73.98452292010728},
#     'southwest': {'lat': 40.75635897010727, 'lng': -73.98722257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Line Friends New York Times Square Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105946118799498782593">Anna Muniz</a>'],
#     'photo_reference': 'Aap_uEB6K_236VxenR8O3F_Bdz1NoCFBKm6JWUdqo8lvZseyBtAr9FXkhmDzcojvNkxwSS9RapfWI16ev-_Et_RKnpOnkAEQFMlTFXCJ7KdXn9axnw-d8sfuRKkS7cD-TJidLbf68oeDac54i0dJ4n4YgpCFvwYlMzeyNjaTV-B1BW2JnAtK',
#     'width': 3024}],
#   'place_id': 'ChIJt1Be91RYwokRq2XhokPaPqI',
#   'plus_code': {'compound_code': 'Q257+4J New York',
#    'global_code': '87G8Q257+4J'},
#   'rating': 4.5,
#   'reference': 'ChIJt1Be91RYwokRq2XhokPaPqI',
#   'types': ['home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 888},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '228 W 47th St #1, New York, NY 10036',
#   'geometry': {'location': {'lat': 40.7596445, 'lng': -73.9862168},
#    'viewport': {'northeast': {'lat': 40.76108032989273,
#      'lng': -73.98478332010727},
#     'southwest': {'lat': 40.75838067010729, 'lng': -73.98748297989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'New York General Store',
#   'permanently_closed': True,
#   'place_id': 'ChIJffbTzFVYwokRyEX9wvP2Za8',
#   'plus_code': {'compound_code': 'Q257+VG New York',
#    'global_code': '87G8Q257+VG'},
#   'rating': 5,
#   'reference': 'ChIJffbTzFVYwokRyEX9wvP2Za8',
#   'types': ['point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 2},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '545 5th Ave, New York, NY 10017',
#   'geometry': {'location': {'lat': 40.7552241, 'lng': -73.9793828},
#    'viewport': {'northeast': {'lat': 40.75654292989272,
#      'lng': -73.97800322010728},
#     'southwest': {'lat': 40.75384327010728, 'lng': -73.98070287989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'NBA Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107134518584108158623">Serhii Kyslyakov</a>'],
#     'photo_reference': 'Aap_uEDLOvJdZZVH3AC5VgiBkYDGnD_FQX6IIoQrFZrg0OgFv7VE8p8E1-ZdN2ES1BlUOLrb9AagxQ6SZJBfmWbxiabS_rD-sNz5BcxIqtPU5InNG6mMcw1hnydTGUNGFa1qUsnRQyQxeQWYyq_AsFLUFIej5-Py4by-nFY6F9Sy--TzjbK0',
#     'width': 5312}],
#   'place_id': 'ChIJzQRpJf5YwokREQQZxSGUD4E',
#   'plus_code': {'compound_code': 'Q24C+36 New York',
#    'global_code': '87G8Q24C+36'},
#   'rating': 4.5,
#   'reference': 'ChIJzQRpJf5YwokREQQZxSGUD4E',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 4588},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '2166 Frederick Douglass Blvd, New York, NY 10026',
#   'geometry': {'location': {'lat': 40.8048198, 'lng': -73.9547643},
#    'viewport': {'northeast': {'lat': 40.80623462989271,
#      'lng': -73.95352347010727},
#     'southwest': {'lat': 40.80353497010727, 'lng': -73.95622312989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet',
#   'name': '2166 convenience store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115048340837209466042">2166 convenience store</a>'],
#     'photo_reference': 'Aap_uECzR9WK5wqdLUthTRUDV3qIDAxEvWpd2x1tkgmoQA8VJ0rnC9rqbCpNaGaxRrPKEAydfNNWnJpJBIIjp8I4hBibO6KceBU-9veVKfAg3CpZFKaGTW7yLkBfdEJwADYGgOVuoj2KfUnNFjyNplbmegCTqJ2Nu01LdiBqB0g3694FS9P_',
#     'width': 3024}],
#   'place_id': 'ChIJSZqkkhb2wokRcp7AQYgWybo',
#   'plus_code': {'compound_code': 'R23W+W3 New York',
#    'global_code': '87G8R23W+W3'},
#   'rating': 5,
#   'reference': 'ChIJSZqkkhb2wokRcp7AQYgWybo',
#   'types': ['convenience_store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '117 E 24th St, New York, NY 10010',
#   'geometry': {'location': {'lat': 40.7406538, 'lng': -73.9849078},
#    'viewport': {'northeast': {'lat': 40.74192432989272,
#      'lng': -73.98361622010728},
#     'southwest': {'lat': 40.73922467010728, 'lng': -73.98631587989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Manhattan Saddlery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 555,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102869030555575305736">Manhattan Saddlery</a>'],
#     'photo_reference': 'Aap_uED9KznyHwfoZwzqAJzRoyCzH1ZWeOgMhhqyKl__oiaFds1Vm92oHpD1Vlrdx0jXpdkEYJ8SGq07ZXpj_buBrrolaGP9D3lkyyJ3wp7OvoD8tACWuD5_ve0OlsShnZ_036Q74YItHn9U6k6dEXX97vyHeIWbg0gbpADZqfeEijNY9fOe',
#     'width': 800}],
#   'place_id': 'ChIJ2cbYzKBZwokRWXcJPIrD2qQ',
#   'plus_code': {'compound_code': 'P2R8+72 New York',
#    'global_code': '87G8P2R8+72'},
#   'rating': 4.6,
#   'reference': 'ChIJ2cbYzKBZwokRWXcJPIrD2qQ',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 82},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '435 Broadway, New York, NY 10013',
#   'geometry': {'location': {'lat': 40.7201718, 'lng': -74.00144259999999},
#    'viewport': {'northeast': {'lat': 40.72149047989272,
#      'lng': -74.00001197010727},
#     'southwest': {'lat': 40.71879082010727, 'lng': -74.0027116298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The shop',
#   'permanently_closed': True,
#   'place_id': 'ChIJ42VAST1ZwokRNDZWKTxptEE',
#   'plus_code': {'compound_code': 'PXCX+3C New York',
#    'global_code': '87G7PXCX+3C'},
#   'rating': 0,
#   'reference': 'ChIJ42VAST1ZwokRNDZWKTxptEE',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '75 9th Ave, New York, NY 10011',
#   'geometry': {'location': {'lat': 40.7427917, 'lng': -74.0063546},
#    'viewport': {'northeast': {'lat': 40.74427557989272,
#      'lng': -74.00508537010728},
#     'southwest': {'lat': 40.74157592010728, 'lng': -74.00778502989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Pearl River Mart',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114604246995929193189">annzie a</a>'],
#     'photo_reference': 'Aap_uEDwPJVEmLYIe1ghoR1iADZ9zv2W4RiXcNrl1P1RUxQ-xdAqBPIf6cFGwv3oX-HqisVTF8SjVYEPpWm-zc7oO3OtVPcRtQ66QM0IcjIkxoopEaWNhipMdnYZfXVtBCiMWe1lYOV0VbKYOOKLHwIdu1YLVDAlpGiluwvybDBwabUrJj2Q',
#     'width': 4160}],
#   'place_id': 'ChIJ4ajlFL9ZwokR-A1xm20cdYQ',
#   'plus_code': {'compound_code': 'PXVV+4F New York',
#    'global_code': '87G7PXVV+4F'},
#   'rating': 4.4,
#   'reference': 'ChIJ4ajlFL9ZwokR-A1xm20cdYQ',
#   'types': ['department_store',
#    'home_goods_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 46},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '114 W 26th St, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.745034, 'lng': -73.99233800000002},
#    'viewport': {'northeast': {'lat': 40.74646562989272,
#      'lng': -73.99093117010727},
#     'southwest': {'lat': 40.74376597010728, 'lng': -73.99363082989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Buffalo Exchange',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1573,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107475238087586144150">Buffalo Exchange</a>'],
#     'photo_reference': 'Aap_uEDmevngTevrB0yPyp0omKwMawvAl6Cvs9LODEsWeIA6vmBx51ZNXth6O1WDF2J7vMlc_EhcG5-AHIOzTmWc8wKuwfMGBq6CNdFvMoxet4iJnrYBkBWnmVKsuS-3o8zqWlLm8X1V6BG2y24oOCwKjIgqO5R9DWEnLLfpZlMztMeOiiYf',
#     'width': 2048}],
#   'place_id': 'ChIJKZ5kDqVZwokR8hNV73Dx8Ms',
#   'plus_code': {'compound_code': 'P2W5+23 New York',
#    'global_code': '87G8P2W5+23'},
#   'price_level': 2,
#   'rating': 3.8,
#   'reference': 'ChIJKZ5kDqVZwokR8hNV73Dx8Ms',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 526},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '151 W 34th St, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.750831, 'lng': -73.9890961},
#    'viewport': {'northeast': {'lat': 40.75208752989272,
#      'lng': -73.98642935000001},
#     'southwest': {'lat': 40.74938787010727, 'lng': -73.99188154999999}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': "Macy's",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107799856362598084959">Jeffrey So</a>'],
#     'photo_reference': 'Aap_uEDCW4aErDXWm1Jx9XbQOwFqRVjTnnXMfmFIe5xPkoTgDiwDTk7nBGi9-Lt1KPA47UVyuGf3EdWJMnc7OedczHg6SgA39ySCR741S-zwbeTjECp3yJCzl24Sfkq4B3DxLaRe4IED3nbc_mw99YYq2sAMUMQma6p_VtkgNjYUJ90jUuce',
#     'width': 4032}],
#   'place_id': 'ChIJ3xjWra5ZwokRrwJ0KZ4yKNs',
#   'plus_code': {'compound_code': 'Q226+89 New York',
#    'global_code': '87G8Q226+89'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJ3xjWra5ZwokRrwJ0KZ4yKNs',
#   'types': ['department_store',
#    'shoe_store',
#    'jewelry_store',
#    'furniture_store',
#    'home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 59409},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1201 3rd Ave, New York, NY 10021',
#   'geometry': {'location': {'lat': 40.768116, 'lng': -73.96144919999999},
#    'viewport': {'northeast': {'lat': 40.76956392989272,
#      'lng': -73.96020637010726},
#     'southwest': {'lat': 40.76686427010728, 'lng': -73.96290602989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Target',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110010486648405738264">yitzchok L</a>'],
#     'photo_reference': 'Aap_uECArb1eNzcS8vigNorEy1acmpU-baXvvDi4PlaQlOnGKCjhqR6PVqcTSgN4kLIkl-6_XcGqAEA8HaLUBxjNlN2h2RMECaOaQTmqgi9_C3NJBOqksuNZ7kTXesD7teu6X-QSWYPPAj4btKW9EhzbI3KcJ2DvW8K-F0Yok4NY8SOCqykJ',
#     'width': 4032}],
#   'place_id': 'ChIJo1xeUdhZwokRCEJuix974eI',
#   'plus_code': {'compound_code': 'Q29Q+6C New York',
#    'global_code': '87G8Q29Q+6C'},
#   'rating': 4.1,
#   'reference': 'ChIJo1xeUdhZwokRCEJuix974eI',
#   'types': ['department_store',
#    'grocery_or_supermarket',
#    'electronics_store',
#    'furniture_store',
#    'home_goods_store',
#    'food',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 662},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '521 5th Ave, New York, NY 10175',
#   'geometry': {'location': {'lat': 40.7541314, 'lng': -73.9798826},
#    'viewport': {'northeast': {'lat': 40.75550382989272,
#      'lng': -73.97870922010728},
#     'southwest': {'lat': 40.75280417010728, 'lng': -73.98140887989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Urban Outfitters',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104386132997549304923">Maarten Schäfer</a>'],
#     'photo_reference': 'Aap_uEC4-WVA238gZMVaZ--ilhgCnSxSzP7TPRb5LlghxKc7uygGT6KzzaXK5pBFpF7y5g95AtOnNIRu_k01wPP0OATjaqcWkZRoYwjSlON0qkwR0hAcOPPDlyQd2VT5v7nwYAk20rpXLiFiM2ZTpeHj4tMH62hpOmllokKzH64QTLaYHkWb',
#     'width': 4032}],
#   'place_id': 'ChIJVZZL0gFZwokR3LhSTVPHh8U',
#   'plus_code': {'compound_code': 'Q23C+M2 New York',
#    'global_code': '87G8Q23C+M2'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJVZZL0gFZwokR3LhSTVPHh8U',
#   'types': ['clothing_store',
#    'shoe_store',
#    'electronics_store',
#    'home_goods_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1704},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '117 E 24th St, New York, NY 10010',
#   'geometry': {'location': {'lat': 40.7406538, 'lng': -73.9849078},
#    'viewport': {'northeast': {'lat': 40.74192432989272,
#      'lng': -73.98361622010728},
#     'southwest': {'lat': 40.73922467010728, 'lng': -73.98631587989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Manhattan Saddlery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 555,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102869030555575305736">Manhattan Saddlery</a>'],
#     'photo_reference': 'Aap_uEBcuSoR3LgB_UD1EkWC3h3cD83EZAhJKz4WE-bU0ud6pzgDxMo7Tbikw_fEBOzH1OEB81Nyr0tiVdVE5TMDEjt91XMr9Yxg4Zo1QNBAGLNCPsjq1D85UrchnTUgLBOW38HZ6KmkjPh1IWzJ2mo7SxOcpxPPtHSs0Er9YB6KyCbeiJap',
#     'width': 800}],
#   'place_id': 'ChIJ2cbYzKBZwokRWXcJPIrD2qQ',
#   'plus_code': {'compound_code': 'P2R8+72 New York',
#    'global_code': '87G8P2R8+72'},
#   'rating': 4.6,
#   'reference': 'ChIJ2cbYzKBZwokRWXcJPIrD2qQ',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 82},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '100 W 33rd St, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.7493107, 'lng': -73.98929849999999},
#    'viewport': {'northeast': {'lat': 40.75060527989272, 'lng': -73.9877179},
#     'southwest': {'lat': 40.74790562010728, 'lng': -73.99041829999999}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Manhattan Mall',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101578299771770686797">Alan St.onge</a>'],
#     'photo_reference': 'Aap_uEC6LYuNI3mxegKcMTQC4PF-_WXGRHcBghuj1SvHGl5yD40chjX9k7ocj634vuO1tsrRv-ReXsQd0HnrcHb6xjMlcHNNGuA2Wa_zNzBElprwa1nrwa-tpphgC2pcc6A85zJ4o2KkaqezReM9XSXd5o_qA6YYF5Ua0uoroHUcsa4dl6r9',
#     'width': 4032}],
#   'place_id': 'ChIJ6-70LKlZwokRzdXlGpoA_so',
#   'plus_code': {'compound_code': 'P2X6+P7 New York',
#    'global_code': '87G8P2X6+P7'},
#   'rating': 4,
#   'reference': 'ChIJ6-70LKlZwokRzdXlGpoA_so',
#   'types': ['shopping_mall', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 7938},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '334 Lexington Ave, New York, NY 10016',
#   'geometry': {'location': {'lat': 40.7497237, 'lng': -73.9775697},
#    'viewport': {'northeast': {'lat': 40.75102222989272,
#      'lng': -73.97625762010729},
#     'southwest': {'lat': 40.74832257010728, 'lng': -73.97895727989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Small Shop and Stop',
#   'permanently_closed': True,
#   'place_id': 'ChIJf3hmUQFZwokRI2WfbWaIJ0A',
#   'plus_code': {'compound_code': 'P2XC+VX New York',
#    'global_code': '87G8P2XC+VX'},
#   'rating': 0,
#   'reference': 'ChIJf3hmUQFZwokRI2WfbWaIJ0A',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '445 W 49th St, New York, NY 10019',
#   'geometry': {'location': {'lat': 40.763806, 'lng': -73.99130699999999},
#    'viewport': {'northeast': {'lat': 40.76509502989272,
#      'lng': -73.98998767010728},
#     'southwest': {'lat': 40.76239537010728, 'lng': -73.99268732989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Fine And Dandy Shop',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2560,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105158225585614513310">venessa soto</a>'],
#     'photo_reference': 'Aap_uEAPy9FAgoPlfD8DbU0VvAVN1i32THvN3Z14w4F9YR8H7q0wc0QmlLsV7euby7WXRPnphVYydTXLekXzVETt-AhxpKyYlfNZ8MxGD6ukjpKdooheWvzeRvQsmGg-SiSZs7Isd1F1cgj_FutqBlhBWBSSp86Ua1d_XMEvyhC3p8DCS_4',
#     'width': 1440}],
#   'place_id': 'ChIJ0ZSv_VBYwokRftM-fhwaSdA',
#   'plus_code': {'compound_code': 'Q275+GF New York',
#    'global_code': '87G8Q275+GF'},
#   'price_level': 2,
#   'rating': 4.9,
#   'reference': 'ChIJ0ZSv_VBYwokRftM-fhwaSdA',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 83},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '245 W 29th St 8th floor, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.74882059999999, 'lng': -73.9945268},
#    'viewport': {'northeast': {'lat': 40.75006302989272,
#      'lng': -73.99325577010728},
#     'southwest': {'lat': 40.74736337010728, 'lng': -73.99595542989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Manhattan Wardrobe Supply',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108265499063981766028">M K</a>'],
#     'photo_reference': 'Aap_uEBEKpr28RGpR1fmSRwNFgPGUJSwZszRqAA0tlk0v7t1ic1FdCgOgUm_g2f9_HoigLMNlbdMSGcH6AksZmr_3SPxPovUNBBvnrdotMFFWPgG-87FABX29r30-zU4aU5grdEyz01CgicFusps9comAtHxx8RahZtnw-iqwOyA_P2mg4pr',
#     'width': 4032}],
#   'place_id': 'ChIJmc6MJ7BZwokRNVnUt90Aw78',
#   'plus_code': {'compound_code': 'P2X4+G5 New York',
#    'global_code': '87G8P2X4+G5'},
#   'rating': 4.7,
#   'reference': 'ChIJmc6MJ7BZwokRNVnUt90Aw78',
#   'types': ['department_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 210},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '115 W 25th St, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.7445994, 'lng': -73.99258929999999},
#    'viewport': {'northeast': {'lat': 40.74590967989272,
#      'lng': -73.99126847010729},
#     'southwest': {'lat': 40.74321002010728, 'lng': -73.99396812989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Thrift Shop in Manhattan',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJufARCUFZwokRVCTcUT7YFhs',
#   'plus_code': {'compound_code': 'P2V4+RX New York',
#    'global_code': '87G8P2V4+RX'},
#   'rating': 4,
#   'reference': 'ChIJufARCUFZwokRVCTcUT7YFhs',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '366 5th Ave #1, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.7490417, 'lng': -73.9843972},
#    'viewport': {'northeast': {'lat': 40.75037427989272,
#      'lng': -73.98292912010727},
#     'southwest': {'lat': 40.74767462010728, 'lng': -73.9856287798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Tee Bar',
#   'permanently_closed': True,
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104936155337491342443">Lauren Fraclose Osborne</a>'],
#     'photo_reference': 'Aap_uEBcF00-m-SjZpyDE9Gz-4c1Z5FAF0tEt5r4BAmoMW1ZuI--PVEbvW_ti5oOcFzKV5czrKx4SzJYM6vaSFJEwLwdBgStTvLvOybsn-5Dsmc2eUwFmULZc9AVrg5_FW8W4G4xw30EYbdopnVUATghFQmHdQY1AJtYr6VqWBfF46Aee3US',
#     'width': 4032}],
#   'place_id': 'ChIJP5PFv6lZwokRYfRMbaaVcfU',
#   'plus_code': {'compound_code': 'P2X8+J6 New York',
#    'global_code': '87G8P2X8+J6'},
#   'rating': 4,
#   'reference': 'ChIJP5PFv6lZwokRYfRMbaaVcfU',
#   'types': ['point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 41},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '435 Broadway, New York, NY 10013',
#   'geometry': {'location': {'lat': 40.7201718, 'lng': -74.00144259999999},
#    'viewport': {'northeast': {'lat': 40.72149047989272,
#      'lng': -74.00001197010727},
#     'southwest': {'lat': 40.71879082010727, 'lng': -74.0027116298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The shop',
#   'permanently_closed': True,
#   'place_id': 'ChIJ42VAST1ZwokRNDZWKTxptEE',
#   'plus_code': {'compound_code': 'PXCX+3C New York',
#    'global_code': '87G7PXCX+3C'},
#   'rating': 0,
#   'reference': 'ChIJ42VAST1ZwokRNDZWKTxptEE',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Times Square, Manhattan, NY 10036',
#   'geometry': {'location': {'lat': 40.7598896, 'lng': -73.9851142},
#    'viewport': {'northeast': {'lat': 40.76143032989273,
#      'lng': -73.98382997010727},
#     'southwest': {'lat': 40.75873067010728, 'lng': -73.98652962989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The Fashion Shop',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1067,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118419631486254523902">A Google User</a>'],
#     'photo_reference': 'Aap_uEBrAG3BtDSVHvgjOJV6-eLczGdd0H9T0_sCj66Uyot_EgTjxAcg8bolEXvZWt45cOYT0t792D7sBkbHtTkbXbKpH2aCTPE5HQeoarR8NHLphQ3MO3zJc4e4nL8YmHtXRqk9GUDpomdmAMDd08fP1yH5gZPkF_J9wy3JwoveMqMiqpeQ',
#     'width': 800}],
#   'place_id': 'ChIJlcRcm4FZwokRwtLAS0INhBw',
#   'plus_code': {'compound_code': 'Q257+XX Manhattan, New York, NY',
#    'global_code': '87G8Q257+XX'},
#   'rating': 0,
#   'reference': 'ChIJlcRcm4FZwokRwtLAS0INhBw',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '119 W 56th St, New York, NY 10019',
#   'geometry': {'location': {'lat': 40.7642155, 'lng': -73.97845749999999},
#    'viewport': {'northeast': {'lat': 40.76552152989272,
#      'lng': -73.97728232010728},
#     'southwest': {'lat': 40.76282187010727, 'lng': -73.97998197989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Le Petit Shop NYC',
#   'place_id': 'ChIJwfFb4flYwokRbInx3XMdJLo',
#   'plus_code': {'compound_code': 'Q27C+MJ New York',
#    'global_code': '87G8Q27C+MJ'},
#   'rating': 0,
#   'reference': 'ChIJwfFb4flYwokRbInx3XMdJLo',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '10 Columbus Cir, New York, NY 10019',
#   'geometry': {'location': {'lat': 40.7685811, 'lng': -73.9831811},
#    'viewport': {'northeast': {'lat': 40.76970322989272,
#      'lng': -73.98138354999999},
#     'southwest': {'lat': 40.76700357010727, 'lng': -73.98477015}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The Shops at Columbus Circle',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115434677833321734640">Shappy Mehta</a>'],
#     'photo_reference': 'Aap_uEA5VtqxhSRNPXBlTbL5QCwujJjwWF5CQzx13OgaqwDvCAOOjVaTz3GaewSsmAsd4_4Vai8LZ_jHcLZIz4VsjUjHR_2PnGtU734kou9NCrqDM8-wYIvnkrcd4KUe606lde-2WwTjuVc2UnT5ZqnOAkKJ4Xn2zfYGc5cgYyzlDaYaOEcU',
#     'width': 5312}],
#   'place_id': 'ChIJp3PsL_ZYwokRdBcE-3KTjrg',
#   'plus_code': {'compound_code': 'Q298+CP New York',
#    'global_code': '87G8Q298+CP'},
#   'rating': 4.4,
#   'reference': 'ChIJp3PsL_ZYwokRdBcE-3KTjrg',
#   'types': ['shopping_mall', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 8408},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '687 Broadway, New York, NY 10012',
#   'geometry': {'location': {'lat': 40.7281384, 'lng': -73.9947995},
#    'viewport': {'northeast': {'lat': 40.72944132989272,
#      'lng': -73.99334047010728},
#     'southwest': {'lat': 40.72674167010728, 'lng': -73.99604012989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The Evolution Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118167159210472688737">Marco Togni</a>'],
#     'photo_reference': 'Aap_uEDe-1bUK2bRwriXXm0rLCieO4bRpG3jUdLTpzPNGsjQiWjhCShTBSkue8HkvRTBXM6clf7cpc1-a5Ow7IKovGalw-ftbQldEFAO9gH9a2FxhUYNkrAIAxtlElgmZEqvby4Qd8PFdJeFlule9RU-SNMp4ltAnhRQIwcafG0h20QsgOdR',
#     'width': 2000}],
#   'place_id': 'ChIJ7Rljr45ZwokRKsFnqQir1zs',
#   'plus_code': {'compound_code': 'P2H4+73 New York',
#    'global_code': '87G8P2H4+73'},
#   'price_level': 3,
#   'rating': 4.6,
#   'reference': 'ChIJ7Rljr45ZwokRKsFnqQir1zs',
#   'types': ['jewelry_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 648},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '385 9th Ave STE 55, New York, NY 10001',
#   'geometry': {'location': {'lat': 40.7527592, 'lng': -73.9979487},
#    'viewport': {'northeast': {'lat': 40.75405892989271,
#      'lng': -73.99612677010728},
#     'southwest': {'lat': 40.75135927010727, 'lng': -73.99882642989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'NHL Shop New York City',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114398779111941611212">Bradley</a>'],
#     'photo_reference': 'Aap_uEAN5pzKoXlhnB5Nph4FtRWMNaqAKXml5uoDF_IIeZ_vUNFq4S39tLDo_M9gDUL6Vn4CqCvHdvVds8nGGOfSWRo4J1H8gwyJMwke6fjfrlGRukEkZ70RS9b9tO25uEOC-2-4fKCO8gszW2JwFYgOXp3z7Ln5tuyqpwdTIY5wPCSEJDMw',
#     'width': 5312}],
#   'place_id': 'ChIJgYWke_9YwokRim919H0gdVM',
#   'plus_code': {'compound_code': 'Q232+4R New York',
#    'global_code': '87G8Q232+4R'},
#   'rating': 4.3,
#   'reference': 'ChIJgYWke_9YwokRim919H0gdVM',
#   'types': ['point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 1158},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '27 W 8th St, New York, NY 10011',
#   'geometry': {'location': {'lat': 40.7329667, 'lng': -73.99776969999999},
#    'viewport': {'northeast': {'lat': 40.73427802989271,
#      'lng': -73.99646422010727},
#     'southwest': {'lat': 40.73157837010726, 'lng': -73.99916387989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Shop Untitled NYC',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 570,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107074567180296122288">SHOP UNTITLED</a>'],
#     'photo_reference': 'Aap_uEDJ7KLGIUztV7S3Xytqw2l700q5ByFZrjePrBxJHShWArjDr5sIc-a6LFSVtMamf3YDVfMAn0Q373Vx0gx2t2R4urjDwuR3qmdMtf-ZFDxvkwdzKwh3PHuUQ0hO-L8q2r2-k5dhTerH6nP3T4itpux0K8T1b2bE6hhhdLNfNZyHs5v-',
#     'width': 855}],
#   'place_id': 'ChIJc1jRK5dZwokRankYrf0jb88',
#   'plus_code': {'compound_code': 'P2M2+5V New York',
#    'global_code': '87G8P2M2+5V'},
#   'rating': 4.8,
#   'reference': 'ChIJc1jRK5dZwokRankYrf0jb88',
#   'types': ['clothing_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 72},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '1515 Broadway, New York, NY 10036',
#   'geometry': {'location': {'lat': 40.7578341, 'lng': -73.9858859},
#    'viewport': {'northeast': {'lat': 40.75905862989271,
#      'lng': -73.98452292010728},
#     'southwest': {'lat': 40.75635897010727, 'lng': -73.98722257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Line Friends New York Times Square Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105946118799498782593">Anna Muniz</a>'],
#     'photo_reference': 'Aap_uECuVyv58GMxpCkjD3Bjq_wOLUGZnMzQfmdnP04s993PSu7sZSO50N_1_peKj-5JmATcsgC2NRbaVD_Jgwtj97ZUtZq_qeyqPEABPUa8ELEYLjNLYIChHvvvJBLUUocZzz6nTMLS3yEr_iSLikeK8dYIzPCzUauIVeCwc3xEUMucE3PA',
#     'width': 3024}],
#   'place_id': 'ChIJt1Be91RYwokRq2XhokPaPqI',
#   'plus_code': {'compound_code': 'Q257+4J New York',
#    'global_code': '87G8Q257+4J'},
#   'rating': 4.5,
#   'reference': 'ChIJt1Be91RYwokRq2XhokPaPqI',
#   'types': ['home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 888},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '629 6th Ave, New York, NY 10011',
#   'geometry': {'location': {'lat': 40.7403433, 'lng': -73.994933},
#    'viewport': {'northeast': {'lat': 40.74164222989272,
#      'lng': -73.99347882010728},
#     'southwest': {'lat': 40.73894257010728, 'lng': -73.99617847989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'The Container Store',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102758092598343221370">A Google User</a>'],
#     'photo_reference': 'Aap_uED-2VPx4LnnG0Ow6bITXe7Dwc42FtKSuihV3IN7C65gRN7qTSzi26fIHeBulQfp5Qdm6cDGqMi0V1ohp4EWhw3rlVGpKcuxmgp2fKOV5UfzqnqVGph9j3VZZaQ8H1rYmeUPIU12_mZxmgCTOl9VFntuBGY8X6BM7iQnditapwWTWoFl',
#     'width': 4032}],
#   'place_id': 'ChIJlzpEM6NZwokRHEmZ4wh60aI',
#   'plus_code': {'compound_code': 'P2R4+42 New York',
#    'global_code': '87G8P2R4+42'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJlzpEM6NZwokRHEmZ4wh60aI',
#   'types': ['home_goods_store',
#    'furniture_store',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1279},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '112 W 34th St, New York, NY 10120',
#   'geometry': {'location': {'lat': 40.7498313, 'lng': -73.9887048},
#    'viewport': {'northeast': {'lat': 40.75118112989272,
#      'lng': -73.98735497010726},
#     'southwest': {'lat': 40.74848147010727, 'lng': -73.99005462989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Target',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107821815236197059478">sinan erel</a>'],
#     'photo_reference': 'Aap_uECjK4XyeZJtCRAKWcuBsb1JYvm12lADBcMGW9kqiy2EykNT9tisnz6GZ7pz_wixSkK2-YjS3BjWjb7C_OyPLE9wwKiNypZguEjR6546PZR3pIjhG5BftM2r5HB1g0pfgjYDfX7GoebNBlspvpxXDUQiEe6OKW2X9yOJSfx-R_lfcskv',
#     'width': 1152}],
#   'place_id': 'ChIJsdA-sa5ZwokRPNShF3C2zas',
#   'plus_code': {'compound_code': 'P2X6+WG New York',
#    'global_code': '87G8P2X6+WG'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJsdA-sa5ZwokRPNShF3C2zas',
#   'types': ['department_store',
#    'electronics_store',
#    'furniture_store',
#    'home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 716},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '147 E 57th St, New York, NY 10022',
#   'geometry': {'location': {'lat': 40.7608947, 'lng': -73.96846959999999},
#    'viewport': {'northeast': {'lat': 40.76215197989273,
#      'lng': -73.96718747010728},
#     'southwest': {'lat': 40.75945232010728, 'lng': -73.96988712989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Hammacher Schlemmer',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118167159210472688737">Marco Togni</a>'],
#     'photo_reference': 'Aap_uEDu0kEwjk-HwI_A8a2HEbn4c6OAZP4HJS9V6BC6du3ai_lU2vWqjLXTyzK2ROwpDuZhvdNzZhqSnb8a-L6nl9AgzHRW4wVyw31tQ3-ML0zRSbAObsuJVxJ61XS_Qb-J8jdzh5bVEGxrIA3PEjNUc_XuSlGQ4ckMUo1ayshMY4TRXQwF',
#     'width': 2000}],
#   'place_id': 'ChIJ5U85AeVYwokR8VnEaCw6dl0',
#   'plus_code': {'compound_code': 'Q26J+9J New York',
#    'global_code': '87G8Q26J+9J'},
#   'rating': 3.8,
#   'reference': 'ChIJ5U85AeVYwokR8VnEaCw6dl0',
#   'types': ['department_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 258},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '30 Rockefeller Plaza, New York, NY 10111',
#   'geometry': {'location': {'lat': 40.758761, 'lng': -73.979345},
#    'viewport': {'northeast': {'lat': 40.76019942989272,
#      'lng': -73.97825547010729},
#     'southwest': {'lat': 40.75749977010727, 'lng': -73.98095512989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'FAO Schwarz',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110114490717682934466">Jamie Kuo</a>'],
#     'photo_reference': 'Aap_uEAj93ItyT3dHOy3wEHPjV9KdwXVRo5GDnsVHDSAWeaMsS6OJmocj4KC471HxV7xcoPbYojDNs2uDVNjfdjmymducnIDytIgGSJqtePK57mY3ndSkkTJIlR3rhpF294oD_iA_26rjpkiojTgDRb9_jq6h34YiPWV0xT1A1KH0rs6JFV5',
#     'width': 4032}],
# ...
#    'global_code': '87G8M2R7+7H'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJnWBBYUxawokRXIflzGoBhS0',
#   'types': ['department_store',
#    'shoe_store',
#    'jewelry_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 5865},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '356 Millburn Ave, Millburn, NJ 07041',
#   'geometry': {'location': {'lat': 40.72350489999999, 'lng': -74.3079752},
#    'viewport': {'northeast': {'lat': 40.72494327989271,
#      'lng': -74.30660657010728},
#     'southwest': {'lat': 40.72224362010727, 'lng': -74.30930622989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Roxy Shoes',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJr2NRDiusw4kRwF0qowmr8ac',
#   'plus_code': {'compound_code': 'PMFR+CR Millburn, New Jersey',
#    'global_code': '87G7PMFR+CR'},
#   'rating': 4.4,
#   'reference': 'ChIJr2NRDiusw4kRwF0qowmr8ac',
#   'types': ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 12},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '2917 Long Beach Rd, Oceanside, NY 11572',
#   'geometry': {'location': {'lat': 40.63995449999999, 'lng': -73.6395385},
#    'viewport': {'northeast': {'lat': 40.64126987989272,
#      'lng': -73.63832797010728},
#     'southwest': {'lat': 40.63857022010728, 'lng': -73.64102762989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Medshoes, Inc.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114438939915577468693">A Google User</a>'],
#     'photo_reference': 'Aap_uEDvBh-cqWeYNfPIYwamkXRjifWWQf4WXtqtAwgzdbcn-LheS5dMiAsvtEUhIZfTGYORZzweBqL0UbTU14p40JB6D3dF0EyGXnU-8oBWgsAHwZ2noLgObpJMCBcDzdsCvcsTYUGySzFZj2zE9UajysM8Jw7YPAxPAT4v_xhP9asbIQdc',
#     'width': 3024}],
#   'place_id': 'ChIJ_Sb1SDp7wokRZCpx2kvvd4E',
#   'plus_code': {'compound_code': 'J9Q6+X5 Oceanside, New York',
#    'global_code': '87G8J9Q6+X5'},
#   'rating': 0,
#   'reference': 'ChIJ_Sb1SDp7wokRZCpx2kvvd4E',
#   'types': ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '3482 Palisades Center Dr B304, West Nyack, NY 11758',
#   'geometry': {'location': {'lat': 41.0969972, 'lng': -73.9564848},
#    'viewport': {'northeast': {'lat': 41.09809497989271,
#      'lng': -73.95484297010728},
#     'southwest': {'lat': 41.09539532010727, 'lng': -73.95754262989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Papaya Clothing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105170431124683218627">Marc Gonzalez</a>'],
#     'photo_reference': 'Aap_uECfBeAeDoz4LQH3bfylRia-fPW-LcNfFR5R0KdV0PNuF7JhMKH1oTgVoG67RdT9m0j2as74e26PclLBRgtzcOrAUAUK64e4co7uxeWHJdaNHIcQDJjkVNzW2I826SFbM4fHeo2cswYxGGKekbzQxYbIyhNj-kKGJpvloBrYW9JOHxDY',
#     'width': 2592}],
#   'place_id': 'ChIJac6y9A7V6YkRMSIqO_AfAo8',
#   'plus_code': {'compound_code': '32WV+QC West Nyack, New York',
#    'global_code': '87H832WV+QC'},
#   'rating': 3.9,
#   'reference': 'ChIJac6y9A7V6YkRMSIqO_AfAo8',
#   'types': ['point_of_interest', 'clothing_store', 'store', 'establishment'],
#   'user_ratings_total': 60},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '4862 Big Island Drive, Jacksonville, FL 32246',
#   'geometry': {'location': {'lat': 30.2535207, 'lng': -81.53195869999999},
#    'viewport': {'northeast': {'lat': 30.25485667989272,
#      'lng': -81.53048612010728},
#     'southwest': {'lat': 30.25215702010728, 'lng': -81.53318577989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'REI',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1060,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104839405624039000001">Tri(k Ph0togr@phy</a>'],
#     'photo_reference': 'Aap_uEAJfVGFoHq1BeD4-63_osKWlKJOR-3573hgJ4WlEM44Ne4KQg7vZnUxFp2_HWabITiTJdiddNGaZRj8z7z6s2zPZOoiSSqgumum_Im36khsyuO-p99VI7HVBtH5S-bKa5z_M-pS1P_j6V_LzJ3Nr21w-iUvjBwDCLXS234e_wDCdw8n',
#     'width': 1885}],
#   'place_id': 'ChIJ_-gtfqfK5YgRQ-fSskkuyoc',
#   'plus_code': {'compound_code': '7F39+C6 Windy Hill, Jacksonville, FL',
#    'global_code': '862W7F39+C6'},
#   'rating': 4.6,
#   'reference': 'ChIJ_-gtfqfK5YgRQ-fSskkuyoc',
#   'types': ['shoe_store',
#    'bicycle_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 334},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '10801 Corkscrew Rd Suite #101, Estero, FL 33928',
#   'geometry': {'location': {'lat': 26.4342624, 'lng': -81.7758982},
#    'viewport': {'northeast': {'lat': 26.43565372989272,
#      'lng': -81.77485472010727},
#     'southwest': {'lat': 26.43295407010728, 'lng': -81.77755437989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': "Bloomingdale's Outlet",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111652872131274615787">Mark Jaske</a>'],
#     'photo_reference': 'Aap_uEBs6X9VuOQaP-x-sVHUXxdksmc2W5HNHfT6PHztNJlbtDPg9H8paY7I-DQR7P7rIcUupMpcqImvpu8BFeBELE7Ztju1ZU_h9loGe9wzgMiaz5SpwTiPdlG7G_gSIro7_nYtC64oeO-IPH0eJAKTDEvDHENy0UVpE0WO1dwb3o8xooVr',
#     'width': 4032}],
#   'place_id': 'ChIJd3-niDYR24gRqde_TdJ2Z8o',
#   'plus_code': {'compound_code': 'C6MF+PJ Estero, Florida',
#    'global_code': '76RWC6MF+PJ'},
#   'rating': 4.2,
#   'reference': 'ChIJd3-niDYR24gRqde_TdJ2Z8o',
#   'types': ['department_store',
#    'shoe_store',
#    'jewelry_store',
#    'furniture_store',
#    'home_goods_store',
#    'point_of_interest',
#    'clothing_store',
#    'store',
#    'establishment'],
#   'user_ratings_total': 453},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Mutual Height, Cnr Parliamant & Longmarket St, 14 Darling St, Cape Town, 8001, South Africa',
#   'geometry': {'location': {'lat': -33.92472190000001, 'lng': 18.421795},
#    'viewport': {'northeast': {'lat': -33.92332197010728,
#      'lng': 18.42307177989272},
#     'southwest': {'lat': -33.92602162989272, 'lng': 18.42037212010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Timemate',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJCY44YmNnzB0RouXYzJlVMXQ',
#   'plus_code': {'compound_code': '3CGC+4P Cape Town, South Africa',
#    'global_code': '4FRW3CGC+4P'},
#   'rating': 0,
#   'reference': 'ChIJCY44YmNnzB0RouXYzJlVMXQ',
#   'types': ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Shop 6106, Ground Floor, Victoria & Alfred Waterfront, Cape Town, 8002, South Africa',
#   'geometry': {'location': {'lat': -33.9039102, 'lng': 18.4204114},
#    'viewport': {'northeast': {'lat': -33.90280077010728,
#      'lng': 18.42143057989272},
#     'southwest': {'lat': -33.90550042989273, 'lng': 18.41873092010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Crocs Concept Store',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1496,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113801809933464107930">Mimi Abdul Rashid</a>'],
#     'photo_reference': 'Aap_uEC2JyG-xH3lxQNs2rLOAYjp9oKawhcq6MKMVPzUETonYYnJNEvKyP34jBFSEmJvAY4uoK193U6Dhr87kSmSxVtfHxtBLQSNWAdKcRKLJjm2ddIWeFFR_9X9VS9v_rCC8Oa-8dVmuekNi5JfcE-N2MtS5ai8zGPMcqIdOkLn-Bfv_pg6',
#     'width': 2256}],
#   'place_id': 'ChIJHT-j6lBnzB0R-P1_ft1yet0',
#   'plus_code': {'compound_code': '3CWC+C5 Cape Town, South Africa',
#    'global_code': '4FRW3CWC+C5'},
#   'rating': 3.5,
#   'reference': 'ChIJHT-j6lBnzB0R-P1_ft1yet0',
#   'types': ['shoe_store', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 17},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Żabi Kruk 10, 80-822 Gdańsk, Poland',
#   'geometry': {'location': {'lat': 54.3439384, 'lng': 18.6487288},
#    'viewport': {'northeast': {'lat': 54.34533317989273,
#      'lng': 18.65011587989272},
#     'southwest': {'lat': 54.34263352010728, 'lng': 18.64741622010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Szlachetne Zdrowie-Sklep Medyczny-Zaopatrzenie Ortopedyczne-Gdańsk',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1152,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107637742994812790054">A Google User</a>'],
#     'photo_reference': 'Aap_uEBDo49R8LzWUVBrrIJNVxir03MHLiEnoVK1Wv1qrjdjGfuTpuCwZ5X1UJdoNM3UFUXoogekcTU5DCZQbBbuqNz7RRg7DxtMQqfDbtUwD31yFyppY1qRFXfZm6kytYcbqbHoOuPRsypq0c6CQnIZ35EgcqvpopGjf1hpDFIgcnSM61Y',
#     'width': 2048}],
#   'place_id': 'ChIJBaneg5hz_UYR9liUx6naTKg',
#   'plus_code': {'compound_code': '8JVX+HF Gdańsk, Poland',
#    'global_code': '9F6W8JVX+HF'},
#   'rating': 5,
#   'reference': 'ChIJBaneg5hz_UYR9liUx6naTKg',
#   'types': ['shoe_store',
#    'health',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 70},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Gate No 4, Trade View Building, Utopia City, Pandurang Budhkar Marg, Lower Parel, Mumbai, Maharashtra 400013, India',
#   'geometry': {'location': {'lat': 19.0045611, 'lng': 72.82604839999999},
#    'viewport': {'northeast': {'lat': 19.00591092989272,
#      'lng': 72.82739822989271},
#     'southwest': {'lat': 19.00321127010728, 'lng': 72.82469857010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'SMAAASH',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109780935799372319219">A Google User</a>'],
#     'photo_reference': 'Aap_uEBQsIhvTd3eF9uKpgWW0cnuTNsWdJiLU30Or9iCvO8Iytf4M_P7THx7fAB0FqMwnjsfPR-W4-CqNTKWGTDw3fmmVZXwfynt0fasAazWgoWJprdvzUoWkGL0wJec2Kqb2clTfTmMT1PSN7x8EErHLmfxsaco04gp1kavNKuC3evSV3hx',
#     'width': 1800}],
#   'place_id': 'ChIJi_IYQtHO5zsRL16FQNvidIA',
#   'plus_code': {'compound_code': '2R3G+RC Mumbai, Maharashtra, India',
#    'global_code': '7JFJ2R3G+RC'},
#   'rating': 4.3,
#   'reference': 'ChIJi_IYQtHO5zsRL16FQNvidIA',
#   'types': ['bowling_alley',
#    'amusement_park',
#    'bar',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 10565},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Butterfield Business Park, 2A The Quad, Luton LU2 8EF, United Kingdom',
#   'geometry': {'location': {'lat': 51.91222759999999, 'lng': -0.3892041},
#    'viewport': {'northeast': {'lat': 51.91356377989271,
#      'lng': -0.3880025201072778},
#     'southwest': {'lat': 51.91086412010727, 'lng': -0.3907021798927222}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'American Dream Hair Extensions',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2592,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112793548660844525021">Mustafa Kutbuddin</a>'],
#     'photo_reference': 'Aap_uEAdTLPs2glEiVTQ54NKD-V5RccFnNrBq2UAeryrsrcXCPv_dtUx1rC2Gm1hgJcHmAN70WhWfCefGJyRJ6AKlkKCu5FEHQ08rrnOPaW3hzRKwa5d_6B7e7lQaiSaW2Q3MRqK8pHXrC6DXN20GAzw3VQPVbsWefyu7WVpCnMSUThS1h5R',
#     'width': 4608}],
#   'place_id': 'ChIJjd8EoxYSdkgR_buZkt81U_s',
#   'plus_code': {'compound_code': 'WJ66+V8 Luton, United Kingdom',
#    'global_code': '9C3XWJ66+V8'},
#   'rating': 4.3,
#   'reference': 'ChIJjd8EoxYSdkgR_buZkt81U_s',
#   'types': ['hair_care', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 18},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '24 Barton Dock Rd, Trafford Park, Stretford, Manchester M41 7GF, United Kingdom',
#   'geometry': {'location': {'lat': 53.4635961, 'lng': -2.3382805},
#    'viewport': {'northeast': {'lat': 53.46501757989272,
#      'lng': -2.336934870107278},
#     'southwest': {'lat': 53.46231792010727, 'lng': -2.339634529892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Williams Manchester Jaguar',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117653954498023980244">A Google User</a>'],
#     'photo_reference': 'Aap_uEDINwOFri-JXDsE3kJExvInEDboVUcX6vuF9KTzc3MLMvCUYI-L-EDPEf57E0fhIFSRZiS4e-ImnDMTt7r2Iwx7zxdXOJT2YRB83-FTZntS6jNhnQUqL7_wP1-3Of_dsdChaUg_SqfWhcetmk6vX5ldLsvAy7u26hgnfV_QoZK7MjDK',
#     'width': 1811}],
#   'place_id': 'ChIJhyqEEoaxe0gRLjP_9vowfgE',
#   'plus_code': {'compound_code': 'FM76+CM Manchester, United Kingdom',
#    'global_code': '9C5VFM76+CM'},
#   'rating': 4.2,
#   'reference': 'ChIJhyqEEoaxe0gRLjP_9vowfgE',
#   'types': ['car_dealer', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 205},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': '99 Windsor St, Manchester M5 4DG, United Kingdom',
#   'geometry': {'location': {'lat': 53.48043879999999, 'lng': -2.2791784},
#    'viewport': {'northeast': {'lat': 53.48174732989272,
#      'lng': -2.277810920107278},
#     'southwest': {'lat': 53.47904767010728, 'lng': -2.280510579892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Robins & Day Peugeot Manchester',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1093,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112923835375551087951">Robins &amp; Day Manchester</a>'],
#     'photo_reference': 'Aap_uEAz2zcuUPKbKOay-9e9VL9YbKpsz1AptRAfcdl_QQoKX89Ta3JKXfRn2m2cnodqBbDo-Xuwz8ZguhKB7qt01N1IRMLV-6jQTSTD_ELMMXqzvvnhNABPoL5lnjuRiVs2xgd_Y-sHV5IqBi-z1hJTY5QMtNAucNlhrT43-rvIMYDaM-Aq',
#     'width': 3705}],
#   'place_id': 'ChIJc7I64Dyue0gR_azrKNrRe6E',
#   'plus_code': {'compound_code': 'FPJC+58 Manchester, United Kingdom',
#    'global_code': '9C5VFPJC+58'},
#   'rating': 4.1,
#   'reference': 'ChIJc7I64Dyue0gR_azrKNrRe6E',
#   'types': ['car_dealer',
#    'car_repair',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 480}]

# %%
len(shops)
# Out:
# 483

# %% [markdown]
# Depending on the time when the query is run we get different number of stores but it is always around 500 (e.g. 484, 473, 478 are the actual numbers we got).

# %% [markdown]
# ## Create a dataframe

# %%
# create empty arrays for longitude and latitude
shop_lat= []
shop_lon = []
shop_ids = []
shop_zip =[]

# go through all results and save them to lon and lat arrays

for i in shops:
    shop = i
    
    if shop['place_id'] not in shop_ids:
        shop_ids.append(shop['place_id'])
        try:
            shop_lat.append(shop['geometry']['location']['lat'])
        except:
            shop_lat.append('none')
        try:
            shop_lon.append(shop['geometry']['location']['lng'])
        except:
            shop_lon.append('none')
        try:
            shop_zip.append(shop['formatted_address'])
        except:
            shop_zip.append('none')

# %%
# define dataframe
df_dict= {'id':shop_ids,'longitude':shop_lon,'latitude':shop_lat, 'zip':shop_zip}

shop_df=pd.DataFrame(df_dict)

shop_df
# Out:
#                               id  longitude   latitude  \
# 0    ChIJlzpEM6NZwokRHEmZ4wh60aI -73.994933  40.740343
# 1    ChIJf3hmUQFZwokRI2WfbWaIJ0A -73.977570  40.749724
# 2    ChIJufARCUFZwokRVCTcUT7YFhs -73.992589  40.744599
# 3    ChIJX7ruPlRYwokRtPrnnFkQClQ -73.987207  40.759620
# 4    ChIJERgMok1ZwokRvqpg7_ou5d4 -73.947072  40.783807
# ..                           ...        ...        ...
# 424  ChIJBaneg5hz_UYR9liUx6naTKg  18.648729  54.343938
# 425  ChIJi_IYQtHO5zsRL16FQNvidIA  72.826048  19.004561
# 426  ChIJjd8EoxYSdkgR_buZkt81U_s  -0.389204  51.912228
# 427  ChIJhyqEEoaxe0gRLjP_9vowfgE  -2.338281  53.463596
# 428  ChIJc7I64Dyue0gR_azrKNrRe6E  -2.279178  53.480439
#
#                                                    zip
# 0                      629 6th Ave, New York, NY 10011
# 1                334 Lexington Ave, New York, NY 10016
# 2                    115 W 25th St, New York, NY 10001
# 3                    235 W 46th St, New York, NY 10036
# 4                     1848 2nd Ave, New York, NY 10128
# ..                                                 ...
# 424                Żabi Kruk 10, 80-822 Gdańsk, Poland
# 425  Gate No 4, Trade View Building, Utopia City, P...
# 426  Butterfield Business Park, 2A The Quad, Luton ...
# 427  24 Barton Dock Rd, Trafford Park, Stretford, M...
# 428   99 Windsor St, Manchester M5 4DG, United Kingdom
#
# [429 rows x 4 columns]

# %%
# extract zip
for i in range(len(shop_df)):
    shop_df['zip'][i]=shop_df['zip'][i][-5:]
# Out:
# <ipython-input-7-27e750b1b597>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop_df['zip'][i]=shop_df['zip'][i][-5:]

# %% [markdown]
# ## Remove outliers

# %% [markdown]
# Remove outliers based on the zip code, shops that have their zip code out of range [10001 - 10282] will be removed

# %%
# create a list with indices to remove
rows_to_drop=[]

# %%
# change zip column type str to int - when not possible add these indexes to rows_to_drop 
for x in range(len(shop_df)):
    try:
        shop_df['zip'][x] = int(shop_df['zip'][x])
    except:
        print("not possible to change zip to int in line "+str(x))
        rows_to_drop.append(x)
# Out:
# not possible to change zip to int in line 354
# not possible to change zip to int in line 355
# not possible to change zip to int in line 357
# not possible to change zip to int in line 358
# not possible to change zip to int in line 359
# not possible to change zip to int in line 361
# not possible to change zip to int in line 422
# not possible to change zip to int in line 423
# not possible to change zip to int in line 424
# not possible to change zip to int in line 425
# not possible to change zip to int in line 426
# not possible to change zip to int in line 427
# not possible to change zip to int in line 428
# <ipython-input-9-0861a346fbcd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop_df['zip'][x] = int(shop_df['zip'][x])

# %%
# drop string zips
shop_df.drop(rows_to_drop, axis = 0, inplace = True)

# %%
# initialise one more time a list with indices to remove
rows_to_drop=[]

# %%
# define indexes of shops that are not within the range 10001 - 10282
lower = shop_df['zip'] < 10001
lower_list = lower[lower].index.tolist()
for i in lower_list:
    rows_to_drop.append(i)

higher = shop_df['zip'] > 10282
higher_list = higher[higher].index.tolist()
for i in higher_list:
    rows_to_drop.append(i)

# %%
# print the number of outliers
len(rows_to_drop)
# Out:
# 15

# %%
# print indexes of outliers
rows_to_drop
# Out:
# [349, 352, 360, 417, 350, 351, 353, 356, 396, 415, 416, 418, 419, 420, 421]

# %%
# drop shops not in Manhattan
shop_df.drop(rows_to_drop, axis = 0, inplace = True)

# %%
shop_df
# Out:
#                               id  longitude   latitude    zip
# 0    ChIJlzpEM6NZwokRHEmZ4wh60aI -73.994933  40.740343  10011
# 1    ChIJf3hmUQFZwokRI2WfbWaIJ0A -73.977570  40.749724  10016
# 2    ChIJufARCUFZwokRVCTcUT7YFhs -73.992589  40.744599  10001
# 3    ChIJX7ruPlRYwokRtPrnnFkQClQ -73.987207  40.759620  10036
# 4    ChIJERgMok1ZwokRvqpg7_ou5d4 -73.947072  40.783807  10128
# ..                           ...        ...        ...    ...
# 410  ChIJuV2ik6lZwokROkSPeQIlV3Y -73.958663  40.772844  10075
# 411  ChIJpaSkN4pYwokRfvh_So8V-K4 -73.980556  40.778333  10023
# 412  ChIJr4XGWcZZwokRmpKM5lcKfKs -73.993631  40.726978  10012
# 413  ChIJCyYZYoZYwokR0JPksGwM_ag -73.978402  40.786443  10024
# 414  ChIJN8OiMYxZwokRQOg2qVxYU_8 -74.001559  40.725243  10012
#
# [401 rows x 4 columns]

# %%
#Define coordinates of where we want to center our map
boulder_coords = [40.754932, -73.984016]

#Create the map
my_map = folium.Map(location = boulder_coords, zoom_start = 13)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9c5a0832c8394b719e022cbce9bedd77%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9c5a0832c8394b719e022cbce9bedd77%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9c5a0832c8394b719e022cbce9bedd77%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9c5a0832c8394b719e022cbce9bedd77%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#Define the coordinates we want our markers to be at
for i in range(len(shop_df)):
    folium.Marker([shop_df.iloc[i][2],shop_df.iloc[i][1]], popup = f"Store {i}").add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9c5a0832c8394b719e022cbce9bedd77%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9c5a0832c8394b719e022cbce9bedd77%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9c5a0832c8394b719e022cbce9bedd77%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9c5a0832c8394b719e022cbce9bedd77%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# display indices of rows
ids = []
for i in range(len(shop_df)):
    ids.append(i)
shop_df['id']=ids
shop_df
# Out:
#       id  longitude   latitude    zip
# 0      0 -73.994933  40.740343  10011
# 1      1 -73.977570  40.749724  10016
# 2      2 -73.992589  40.744599  10001
# 3      3 -73.987207  40.759620  10036
# 4      4 -73.947072  40.783807  10128
# ..   ...        ...        ...    ...
# 410  396 -73.958663  40.772844  10075
# 411  397 -73.980556  40.778333  10023
# 412  398 -73.993631  40.726978  10012
# 413  399 -73.978402  40.786443  10024
# 414  400 -74.001559  40.725243  10012
#
# [401 rows x 4 columns]

# %% [markdown]
# # Cluster the results

# %%
# imports
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# ### k-Means

# %%
# define NumPy-Array
X = np.zeros((len(shop_df),2))

X[:,0] = shop_df['latitude']
X[:,1] = shop_df['longitude']
X
# Out:
# array([[ 40.7403433, -73.994933 ],
#        [ 40.7497237, -73.9775697],
#        [ 40.7445994, -73.9925893],
#        [ 40.7596202, -73.9872069],
#        [ 40.7838073, -73.9470725],
#        [ 40.7498313, -73.9887048],
#        [ 40.7508858, -73.9879741],
#        [ 40.7488206, -73.9945268],
#        [ 40.7511748, -73.9716877],
#        [ 40.7578341, -73.9858859],
#        [ 40.7596445, -73.9862168],
#        [ 40.7552241, -73.9793828],
#        [ 40.8048198, -73.9547643],
#        [ 40.7406538, -73.9849078],
#        [ 40.7201718, -74.0014426],
#        [ 40.7427917, -74.0063546],
#        [ 40.745034 , -73.992338 ],
#        [ 40.750831 , -73.9890961],
#        [ 40.768116 , -73.9614492],
#        [ 40.7541314, -73.9798826],
#        [ 40.7493107, -73.9892985],
#        [ 40.763806 , -73.991307 ],
#        [ 40.7490417, -73.9843972],
#        [ 40.7598896, -73.9851142],
#        [ 40.7642155, -73.9784575],
#        [ 40.7685811, -73.9831811],
#        [ 40.7281384, -73.9947995],
#        [ 40.7527592, -73.9979487],
#        [ 40.7329667, -73.9977697],
#        [ 40.7608947, -73.9684696],
#        [ 40.758761 , -73.979345 ],
#        [ 40.7601775, -73.9843631],
#        [ 40.7833601, -73.9524683],
#        [ 40.7351214, -73.9862825],
#        [ 40.7436655, -73.9951853],
#        [ 40.7738489, -73.951809 ],
#        [ 40.7537722, -73.9690028],
#        [ 40.7318431, -73.9886546],
#        [ 40.7959149, -73.9713217],
#        [ 40.7475543, -73.9974252],
#        [ 40.7647437, -73.9789166],
#        [ 40.8042918, -73.9662615],
#        [ 40.7673667, -73.9565889],
#        [ 40.7689628, -73.9852025],
#        [ 40.7644128, -73.964848 ],
#        [ 40.7698251, -73.9603611],
#        [ 40.7394127, -73.9872538],
#        [ 40.7791231, -73.9480369],
#        [ 40.7816574, -73.9580391],
#        [ 40.744453 , -73.999542 ],
#        [ 40.7378369, -73.9801146],
#        [ 40.7579254, -73.9634881],
#        [ 40.7180004, -73.98819  ],
#        [ 40.7136495, -73.9941358],
#        [ 40.7116114, -73.9961107],
#        [ 40.7232516, -73.9960976],
#        [ 40.7223595, -73.9953761],
#        [ 40.7365303, -73.9903945],
#        [ 40.7182566, -73.9881462],
#        [ 40.7184476, -73.9966566],
#        [ 40.7525596, -73.9768066],
#        [ 40.7260635, -73.9833069],
#        [ 40.7428216, -74.0063111],
#        [ 40.7061992, -74.0034706],
#        [ 40.7353992, -73.9901836],
#        [ 40.7387517, -73.9990764],
#        [ 40.7298207, -73.9910749],
#        [ 40.7156249, -73.9871454],
#        [ 40.7314086, -73.9781742],
#        [ 40.7079974, -74.0088826],
#        [ 40.793637 , -73.97215  ],
#        [ 40.7627246, -73.9832546],
#        [ 40.7442146, -73.9887481],
#        [ 40.7557485, -73.9721554],
#        [ 40.7552153, -73.9787657],
#        [ 40.7487667, -73.9920106],
#        [ 40.7635483, -73.9797627],
#        [ 40.7606211, -73.9864374],
#        [ 40.755202 , -73.967987 ],
#        [ 40.7614377, -73.9855281],
#        [ 40.7626274, -73.9808411],
#        [ 40.7668083, -73.9675769],
#        [ 40.740081 , -73.9887509],
#        [ 40.7626593, -73.9714411],
#        [ 40.743099 , -73.9871592],
#        [ 40.7289458, -74.0015062],
#        [ 40.7674251, -73.9811137],
#        [ 40.756175 , -73.9946239],
#        [ 40.7611039, -73.9801635],
#        [ 40.7440762, -73.9949218],
#        [ 40.7460436, -73.9802946],
#        [ 40.738715 , -73.9955791],
#        [ 40.7646749, -73.9824801],
#        [ 40.7617179, -73.9606764],
#        [ 40.7593916, -73.9916209],
#        [ 40.7685841, -73.9855086],
#        [ 40.7469913, -73.9740353],
#        [ 40.7612   , -73.990923 ],
#        [ 40.7636453, -73.9848329],
#        [ 40.7910489, -73.97474  ],
#        [ 40.7069432, -74.0062813],
#        [ 40.75242  , -73.993544 ],
#        [ 40.7533862, -73.9967957],
#        [ 40.7454427, -73.9757313],
#        [ 40.7618723, -73.9834356],
#        [ 40.7533351, -73.9967326],
#        [ 40.7377933, -73.9812265],
#        [ 40.756371 , -73.9717731],
#        [ 40.747671 , -73.9878931],
#        [ 40.7201268, -73.9964692],
#        [ 40.7490193, -73.9871186],
#        [ 40.7514601, -73.9852514],
#        [ 40.7515416, -73.9856612],
#        [ 40.8647217, -73.9190925],
#        [ 40.7533447, -73.9936044],
#        [ 40.7586417, -73.9708158],
#        [ 40.7538306, -73.9916924],
#        [ 40.7541168, -73.9906885],
#        [ 40.7534052, -73.9876422],
#        [ 40.7432981, -73.9864073],
#        [ 40.7520678, -73.9886235],
#        [ 40.726579 , -73.9953126],
#        [ 40.8656412, -73.9197266],
#        [ 40.7454828, -73.9896373],
#        [ 40.7791563, -73.9473114],
#        [ 40.7521009, -73.9849032],
#        [ 40.7469639, -73.9914331],
#        [ 40.735008 , -74.0050629],
#        [ 40.7575662, -73.9685468],
#        [ 40.7220566, -73.9999243],
#        [ 40.7720402, -73.9611857],
#        [ 40.7644555, -73.9805688],
#        [ 40.7842556, -73.9560652],
#        [ 40.7368375, -73.9883799],
#        [ 40.7493545, -73.9894826],
#        [ 40.779781 , -73.959902 ],
#        [ 40.7146619, -74.007106 ],
#        [ 40.7235546, -73.9940682],
#        [ 40.7742072, -73.9576802],
#        [ 40.7264815, -73.9841561],
#        [ 40.7922799, -73.9731712],
#        [ 40.7638819, -73.9777341],
#        [ 40.7190315, -73.9977161],
#        [ 40.7862839, -73.9762556],
#        [ 40.7574831, -73.9899657],
#        [ 40.785239 , -73.955858 ],
#        [ 40.775491 , -73.956809 ],
#        [ 40.7588595, -73.9712746],
#        [ 40.7543295, -73.9864146],
#        [ 40.7690179, -73.9579526],
#        [ 40.7318546, -73.994914 ],
#        [ 40.7558983, -73.9682433],
#        [ 40.761134 , -73.9847476],
#        [ 40.7927269, -73.9737163],
#        [ 40.759498 , -73.9958552],
#        [ 40.7401171, -74.0027977],
#        [ 40.7782493, -73.9562245],
#        [ 40.7676205, -73.958886 ],
#        [ 40.7639862, -73.9623318],
#        [ 40.734939 , -73.9897445],
#        [ 40.7319489, -73.9825438],
#        [ 40.7520595, -73.9802252],
#        [ 40.747725 , -73.9734328],
#        [ 40.7614321, -73.9844628],
#        [ 40.7437466, -73.9918389],
#        [ 40.8041282, -73.9672541],
#        [ 40.7619194, -73.9904178],
#        [ 40.7549941, -73.9917692],
#        [ 40.7799589, -73.9802984],
#        [ 40.7761017, -73.9801351],
#        [ 40.7901886, -73.9468654],
#        [ 40.761253 , -73.990308 ],
#        [ 40.7510254, -73.9954605],
#        [ 40.7661153, -73.9623639],
#        [ 40.7671115, -73.9894391],
#        [ 40.7722982, -73.954946 ],
#        [ 40.758362 , -73.9698216],
#        [ 40.7921279, -73.9385567],
#        [ 40.7422538, -74.0003851],
#        [ 40.7479249, -73.9870192],
#        [ 40.7294208, -73.9845332],
#        [ 40.7571221, -73.9900691],
#        [ 40.7636385, -73.9947182],
#        [ 40.7575745, -73.9713695],
#        [ 40.7979864, -73.9405047],
#        [ 40.780203 , -73.9802612],
#        [ 40.7553789, -73.9733327],
#        [ 40.7604954, -73.9731882],
#        [ 40.7624795, -73.969201 ],
#        [ 40.7851492, -73.9555033],
#        [ 40.753641 , -73.9991966],
#        [ 40.7270258, -73.9945607],
#        [ 40.7610606, -73.9847401],
#        [ 40.740633 , -73.9927017],
#        [ 40.7466065, -74.0047674],
#        [ 40.7569545, -73.990494 ],
#        [ 40.7138286, -73.9909233],
#        [ 40.7557334, -73.9789175],
#        [ 40.75041  , -73.99318  ],
#        [ 40.7568648, -73.9862184],
#        [ 40.7369416, -73.9896278],
#        [ 40.7246035, -73.9965755],
#        [ 40.754107 , -73.9849938],
#        [ 40.7862392, -73.9787281],
#        [ 40.7543343, -73.9773555],
#        [ 40.7386417, -73.9942352],
#        [ 40.7156726, -74.0117482],
#        [ 40.7553583, -73.9721302],
#        [ 40.7457399, -73.9882272],
#        [ 40.7520108, -73.9987181],
#        [ 40.8212995, -73.9444725],
#        [ 40.7613127, -73.9899748],
#        [ 40.7520746, -73.9857387],
#        [ 40.7569428, -73.9834495],
#        [ 40.7541889, -73.9888567],
#        [ 40.7562408, -73.9770571],
#        [ 40.7526208, -73.9878812],
#        [ 40.7697763, -73.9624972],
#        [ 40.7562507, -73.9809498],
#        [ 40.7462091, -73.9895129],
#        [ 40.7453125, -73.9846013],
#        [ 40.739111 , -73.989113 ],
#        [ 40.7452234, -73.9902283],
#        [ 40.7328275, -73.9979664],
#        [ 40.7458662, -74.0051138],
#        [ 40.780399 , -73.953405 ],
#        [ 40.7638094, -73.9666075],
#        [ 40.7588826, -73.9929693],
#        [ 40.7481868, -73.9873383],
#        [ 40.7611203, -73.9769396],
#        [ 40.7526155, -73.9996513],
#        [ 40.7643188, -73.9756526],
#        [ 40.7575336, -73.9791089],
#        [ 40.7531958, -74.000644 ],
#        [ 40.756698 , -73.9897458],
#        [ 40.7607554, -73.9858962],
#        [ 40.7432672, -73.9901338],
#        [ 40.7157276, -73.9940495],
#        [ 40.7538811, -73.9961889],
#        [ 40.7432182, -73.9796728],
#        [ 40.7215521, -73.9967131],
#        [ 40.76045  , -73.9760892],
#        [ 40.737047 , -73.9925674],
#        [ 40.7556676, -73.9870445],
#        [ 40.758704 , -73.9848   ],
#        [ 40.7122455, -73.9940079],
#        [ 40.7493905, -73.9861371],
#        [ 40.7581343, -73.9785412],
#        [ 40.749411 , -73.984258 ],
#        [ 40.8002338, -73.9676361],
#        [ 40.7433574, -73.9887711],
#        [ 40.7378837, -73.9898417],
#        [ 40.7234978, -73.9982019],
#        [ 40.72023  , -73.9839958],
#        [ 40.7410162, -73.9982814],
#        [ 40.7666966, -73.9821026],
#        [ 40.7200747, -73.9977494],
#        [ 40.763648 , -73.9973439],
#        [ 40.764437 , -73.9885436],
#        [ 40.7638811, -73.9852942],
#        [ 40.7531977, -73.9996871],
#        [ 40.7631438, -73.9788554],
#        [ 40.7586252, -73.9704328],
#        [ 40.7609134, -73.982565 ],
#        [ 40.7446778, -73.9908472],
#        [ 40.7571646, -73.987272 ],
#        [ 40.762546 , -73.976704 ],
#        [ 40.7527917, -73.9845972],
#        [ 40.741722 , -73.990672 ],
#        [ 40.728814 , -73.988492 ],
#        [ 40.748267 , -73.990714 ],
#        [ 40.75048  , -73.985896 ],
#        [ 40.743366 , -73.9887037],
#        [ 40.728434 , -73.98802  ],
#        [ 40.766695 , -73.959675 ],
#        [ 40.7905032, -73.9389806],
#        [ 40.7292751, -73.9869556],
#        [ 40.787586 , -73.953737 ],
#        [ 40.7263721, -73.9895465],
#        [ 40.7879146, -73.9772804],
#        [ 40.7495887, -73.9699029],
#        [ 40.7051716, -74.016048 ],
#        [ 40.725184 , -73.987311 ],
#        [ 40.7767299, -73.9795717],
#        [ 40.8362947, -73.94019  ],
#        [ 40.7315023, -74.003355 ],
#        [ 40.7392319, -74.0031452],
#        [ 40.7741352, -73.9511675],
#        [ 40.7633251, -73.9894255],
#        [ 40.7812725, -73.9545819],
#        [ 40.7998138, -73.9685439],
#        [ 40.7546399, -73.9889772],
#        [ 40.7527814, -73.9759322],
#        [ 40.7482436, -73.9851073],
#        [ 40.7695043, -73.988517 ],
#        [ 40.7911217, -73.9431148],
#        [ 40.7446466, -73.9917813],
#        [ 40.7617385, -73.9861904],
#        [ 40.7650362, -73.9823729],
#        [ 40.8084147, -73.9546432],
#        [ 40.7597578, -73.9881806],
#        [ 40.7522665, -73.9757167],
#        [ 40.796423 , -73.9476263],
#        [ 40.7659053, -73.9912197],
#        [ 40.7506424, -73.9980357],
#        [ 40.758922 , -73.9680371],
#        [ 40.755255 , -73.995251 ],
#        [ 40.778984 , -73.947529 ],
#        [ 40.7593039, -73.9663868],
#        [ 40.8148867, -73.9475138],
#        [ 40.7748443, -73.9572329],
#        [ 40.7551715, -73.9924463],
#        [ 40.7674581, -73.9850805],
#        [ 40.7625199, -73.9966348],
#        [ 40.7797504, -73.9839622],
#        [ 40.7748037, -73.9878558],
#        [ 40.7258825, -73.9893093],
#        [ 40.7444539, -73.9956814],
#        [ 40.7414414, -73.9965239],
#        [ 40.7786522, -73.950777 ],
#        [ 40.7780809, -73.980868 ],
#        [ 40.7507174, -73.9857032],
#        [ 40.794634 , -73.9712915],
#        [ 40.7976726, -73.9369236],
#        [ 40.7624425, -73.9937756],
#        [ 40.7995649, -73.9631717],
#        [ 40.7432175, -74.0002884],
#        [ 40.73868  , -74.0040174],
#        [ 40.8663263, -73.9285215],
#        [ 40.7539787, -73.9926454],
#        [ 40.7474965, -73.9891165],
#        [ 40.7486425, -73.9958521],
#        [ 40.7778252, -73.949025 ],
#        [ 40.7518243, -73.9921221],
#        [ 40.7639979, -73.9851384],
#        [ 40.776298 , -73.955481 ],
#        [ 40.7959946, -73.9686316],
#        [ 40.7577618, -73.989631 ],
#        [ 40.709781 , -74.0084716],
#        [ 40.7401815, -73.9858928],
#        [ 40.7265746, -73.9914368],
#        [ 40.7078278, -74.0056597],
#        [ 40.7155613, -74.0053156],
#        [ 40.7370644, -73.9841031],
#        [ 40.7078937, -74.0139088],
#        [ 40.7282564, -73.9816488],
#        [ 40.7135918, -74.0092858],
#        [ 40.7571875, -73.971508 ],
#        [ 40.7541042, -73.9867166],
#        [ 40.7953416, -73.9355575],
#        [ 40.7719457, -73.9525339],
#        [ 40.7649467, -73.9660119],
#        [ 40.7704477, -73.9618276],
#        [ 40.75962  , -73.977363 ],
#        [ 40.7573533, -73.9752435],
#        [ 40.751004 , -73.9843003],
#        [ 40.7401536, -73.9896736],
#        [ 40.7579426, -73.9709996],
#        [ 40.7452624, -73.9930835],
#        [ 40.7517483, -73.9886479],
#        [ 40.7644011, -73.9600274],
#        [ 40.7490087, -73.9953585],
#        [ 40.7646853, -73.9799184],
#        [ 40.7289295, -73.9786714],
#        [ 40.8160394, -73.9464974],
#        [ 40.7474305, -73.9923463],
#        [ 40.7837557, -73.9522871],
#        [ 40.7492732, -73.9822099],
#        [ 40.780946 , -73.954323 ],
#        [ 40.7898619, -73.9433943],
#        [ 40.7747586, -73.9512514],
#        [ 40.7089382, -74.0054616],
#        [ 40.758651 , -73.992178 ],
#        [ 40.7527809, -73.9848709],
#        [ 40.7308276, -74.0004951],
#        [ 40.759946 , -73.96532  ],
#        [ 40.764525 , -73.98792  ],
#        [ 40.7521526, -73.9839834],
#        [ 40.8651462, -73.9194024],
#        [ 40.7077005, -74.0071603],
#        [ 40.8261609, -73.9490816],
#        [ 40.8513504, -73.9318683],
#        [ 40.7418476, -73.9913589],
#        [ 40.7407207, -73.9921264],
#        [ 40.7614618, -73.9668809],
#        [ 40.7395581, -73.9901198],
#        [ 40.7797183, -73.9506192],
#        [ 40.7642913, -73.99719  ],
#        [ 40.7946498, -73.9659842],
#        [ 40.7426734, -73.9894407],
#        [ 40.7847276, -73.9494156],
#        [ 40.8239171, -73.9519501],
#        [ 40.756839 , -73.999141 ],
#        [ 40.7198297, -73.9914203],
#        [ 40.744627 , -73.987716 ],
#        [ 40.7553136, -73.977934 ],
#        [ 40.7728445, -73.9586629],
#        [ 40.7783333, -73.9805556],
#        [ 40.7269776, -73.9936315],
#        [ 40.7864429, -73.9784023],
#        [ 40.7252431, -74.0015595]])

# %%
# apply kmeans
kmeans = KMeans(n_clusters=20, random_state=42)

# %%
# fit kmeans
kmeans.fit(X)
kmeans.get_params()
# Out:
# {'algorithm': 'auto',
#  'copy_x': True,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'n_clusters': 20,
#  'n_init': 10,
#  'n_jobs': 'deprecated',
#  'precompute_distances': 'deprecated',
#  'random_state': 42,
#  'tol': 0.0001,
#  'verbose': 0}

# %%
# show cluster assignment of data items
X_clustered = pd.DataFrame(X)
X_clustered['label'] = kmeans.labels_
X_clustered
# Out:
#              0          1  label
# 0    40.740343 -73.994933      4
# 1    40.749724 -73.977570     10
# 2    40.744599 -73.992589     17
# 3    40.759620 -73.987207      9
# 4    40.783807 -73.947072      3
# ..         ...        ...    ...
# 396  40.772844 -73.958663     15
# 397  40.778333 -73.980556      6
# 398  40.726978 -73.993631     16
# 399  40.786443 -73.978402      6
# 400  40.725243 -74.001559     16
#
# [401 rows x 3 columns]

# %%
# compute cluster centers
cluster_centers = kmeans.cluster_centers_
cluster_centers
# Out:
# array([[ 40.72793761, -73.98575476],
#        [ 40.76336535, -73.98148933],
#        [ 40.84382255, -73.93602915],
#        [ 40.78052856, -73.95257875],
#        [ 40.74176371, -74.00041936],
#        [ 40.75968407, -73.96845802],
#        [ 40.78090353, -73.98034787],
#        [ 40.86545885, -73.92168575],
#        [ 40.71665037, -73.99328618],
#        [ 40.7610085 , -73.98986848],
#        [ 40.75313229, -73.97648368],
#        [ 40.79346966, -73.94128043],
#        [ 40.79683988, -73.96952875],
#        [ 40.70984155, -74.00836924],
#        [ 40.75261382, -73.99585544],
#        [ 40.76983549, -73.95905618],
#        [ 40.72652294, -73.99759313],
#        [ 40.74101573, -73.98894136],
#        [ 40.81650544, -73.94984613],
#        [ 40.75064098, -73.98721814]])

# %%
# show clusters in Map
# define new map
cluster_map = folium.Map(location = boulder_coords, zoom_start = 13)

#Add 20 cluster centroids to the map
for i in range(20):
    folium.Marker([cluster_centers[i,0],cluster_centers[i,1]], popup = f"cluster {i}").add_to(cluster_map)

# %%
#Display the map
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6ab82805e28042179fab36cde9f6d7bd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6ab82805e28042179fab36cde9f6d7bd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6ab82805e28042179fab36cde9f6d7bd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6ab82805e28042179fab36cde9f6d7bd%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# extract number of items in each cluster and collect them in list
members = X_clustered.groupby('label').count()
num = members[0]
num
# Out:
# label
# 0     17
# 1     34
# 2      2
# 3     24
# 4     19
# 5     26
# 6     12
# 7      4
# 8     13
# 9     37
# 10    25
# 11     9
# 12    13
# 13    13
# 14    26
# 15    18
# 16    19
# 17    41
# 18     7
# 19    42
# Name: 0, dtype: int64

# %% [markdown]
# ## Drop clusters that have less than 10 members

# %%
# define labels of cluster that have less than 10 members 
small_hubs = num < 10
small_hubs_list = small_hubs[small_hubs].index.tolist()
small_hubs_list
# Out:
# [2, 7, 11, 18]

# %%
#drop hubs with less than 10 shops
X_clustered = X_clustered[~X_clustered.label.isin(small_hubs_list)]
X_clustered=X_clustered.reset_index(drop=True)

# %%
# extract number of items in each cluster and collect them in list
members = X_clustered.groupby('label').count()
num = members[0]
num
# Out:
# label
# 0     17
# 1     34
# 3     24
# 4     19
# 5     26
# 6     12
# 8     13
# 9     37
# 10    25
# 12    13
# 13    13
# 14    26
# 15    18
# 16    19
# 17    41
# 19    42
# Name: 0, dtype: int64

# %%
new_cluster_centers=np.delete(cluster_centers,small_hubs_list, axis = 0)

# %%
new_cluster_centers
# Out:
# array([[ 40.72793761, -73.98575476],
#        [ 40.76336535, -73.98148933],
#        [ 40.78052856, -73.95257875],
#        [ 40.74176371, -74.00041936],
#        [ 40.75968407, -73.96845802],
#        [ 40.78090353, -73.98034787],
#        [ 40.71665037, -73.99328618],
#        [ 40.7610085 , -73.98986848],
#        [ 40.75313229, -73.97648368],
#        [ 40.79683988, -73.96952875],
#        [ 40.70984155, -74.00836924],
#        [ 40.75261382, -73.99585544],
#        [ 40.76983549, -73.95905618],
#        [ 40.72652294, -73.99759313],
#        [ 40.74101573, -73.98894136],
#        [ 40.75064098, -73.98721814]])

# %% [markdown]
# ## Visualise the size of clusters

# %%
# compute how big cluster circle should be
occurences = folium.map.FeatureGroup()
for i in range(20):
    occurences.add_child(folium.vector_layers.CircleMarker(
    [cluster_centers[i,0],cluster_centers[i,1]],
    radius= num[i]/len(X_clustered)*400,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=1,
    tooltip = str(i)))
cluster_map.add_child(occurences)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1c79273e0f30> in <module>
#       4     occurences.add_child(folium.vector_layers.CircleMarker(
#       5     [cluster_centers[i,0],cluster_centers[i,1]],
# ----> 6     radius= num[i]/len(X_clustered)*400,
#       7     color='blue',
#       8     fill=True,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 2

# %% [markdown]
# ## Visualise shops belonging to certain hub

# %% [markdown]
# Define a function that shows all data points on a map and assigns a colour according to cluster

# %%
def draw_colorful_points(X_clustered):
    # set color scheme for the clusters
    
    #define number of colors (number of unique labels in clustered data)
    no_clusters=len(np.unique(X_clustered['label']))
    x = np.arange(no_clusters)
    ys = [i + x + (i*x)**2 for i in range(no_clusters)]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    #define a new map
    cluster_map_colored = folium.Map(location = boulder_coords, zoom_start = 13)

    # add markers to the map
    markers_colors = []
    for i in range(no_clusters):
        for j in range(len(X_clustered)):
            if (i==X_clustered['label'][j]):
                folium.vector_layers.CircleMarker(
                    [X_clustered[0][j],X_clustered[1][j]],
                    radius=5,
                    tooltip = str(i),
                    color=rainbow[i],
                    fill=True,
                    fill_color=rainbow[i],
                    fill_opacity=0.9).add_to(cluster_map_colored)

    display(cluster_map_colored)

# %%
draw_colorful_points(X_clustered)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4be44a4abe614f98ae84b4ee50b5662a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4be44a4abe614f98ae84b4ee50b5662a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4be44a4abe614f98ae84b4ee50b5662a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4be44a4abe614f98ae84b4ee50b5662a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### DBScan

# %%
# define epsilon and min stores
epsilon=0.0026
min_samples= 10

# %%
# fit dbscan algorithm and define labels
db = DBSCAN(eps=epsilon, min_samples=min_samples).fit(X)
labels = db.labels_

# %%
# check # clusters and # noise points
no_clusters = len(np.unique(labels))
no_noise = np.sum(np.array(labels) == -1, axis=0)

print('Estimated no. of clusters: %d' % no_clusters)
print('Estimated no. of noise points: %d' % no_noise)
# Out:
# Estimated no. of clusters: 6
# Estimated no. of noise points: 275

# %%
X_clustered_db = pd.DataFrame(X)
X_clustered_db['label'] = labels
X_clustered_db
# Out:
#              0          1  label
# 0    40.740343 -73.994933     -1
# 1    40.749724 -73.977570     -1
# 2    40.744599 -73.992589      1
# 3    40.759620 -73.987207      0
# 4    40.783807 -73.947072     -1
# ..         ...        ...    ...
# 396  40.772844 -73.958663     -1
# 397  40.778333 -73.980556     -1
# 398  40.726978 -73.993631     -1
# 399  40.786443 -73.978402     -1
# 400  40.725243 -74.001559     -1
#
# [401 rows x 3 columns]

# %%
draw_colorful_points(X_clustered_db)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c5b2b402e09c44ceaa8469c2581cbecb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c5b2b402e09c44ceaa8469c2581cbecb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c5b2b402e09c44ceaa8469c2581cbecb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c5b2b402e09c44ceaa8469c2581cbecb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.754932%2C%20-73.984016%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
points_of_cluster = X_clustered_db[X_clustered_db['label']==0]
centroid_of_cluster = np.mean(points_of_cluster, axis=0) 
centroid_of_cluster['label']
# Out:
# 0.0

# %%
# print centroids of dbscan clusters
cluster_centers_db = pd.DataFrame()

for i in range(no_clusters-1):
    points_of_cluster = X_clustered_db[X_clustered_db['label']==i]
    centroid_of_cluster = np.mean(points_of_cluster, axis=0) 
    cluster_centers_db.loc[i,0]=centroid_of_cluster[0]
    cluster_centers_db.loc[i,1]=centroid_of_cluster[1]
    cluster_centers_db.loc[i,2]=centroid_of_cluster['label']
cluster_centers_db
# Out:
#            0          1    2
# 0  40.760929 -73.984882  0.0
# 1  40.747706 -73.988371  1.0
# 2  40.757301 -73.971180  2.0
# 3  40.755811 -73.978790  3.0
# 4  40.763592 -73.979009  4.0

# %%
# extract number of items in each cluster and collect them in list
members = X_clustered_db.groupby('label').count()
num = members[0]
num
# Out:
# label
# -1    275
#  0     26
#  1     69
#  2     12
#  3     10
#  4      9
# Name: 0, dtype: int64

# %% [markdown]
# It is problematic to find the apropriate epsilon for dbscan. If epsilon is too small, then the clusters are small and we get many noisy points. But then if we increase the epsilon, the number of clusters decreases, which is not good as we want to have more hubs with less shops. To see the problem, run first the code with epsilon set to 0.002 and then with 0.003. The best trade-off seems to be 0.0026. With these settings we have 4 hubs and 279 noisy points.

# %% [markdown]
# ## Save coordinates of clusters generated with k-means

# %%
new_cluster_centers
# Out:
# array([[ 40.72793761, -73.98575476],
#        [ 40.76336535, -73.98148933],
#        [ 40.78052856, -73.95257875],
#        [ 40.74176371, -74.00041936],
#        [ 40.75968407, -73.96845802],
#        [ 40.78090353, -73.98034787],
#        [ 40.71665037, -73.99328618],
#        [ 40.7610085 , -73.98986848],
#        [ 40.75313229, -73.97648368],
#        [ 40.79683988, -73.96952875],
#        [ 40.70984155, -74.00836924],
#        [ 40.75261382, -73.99585544],
#        [ 40.76983549, -73.95905618],
#        [ 40.72652294, -73.99759313],
#        [ 40.74101573, -73.98894136],
#        [ 40.75064098, -73.98721814]])

# %%
df=pd.DataFrame(new_cluster_centers, columns=['latitude', 'longitude'])

# %%
df
# Out:
#      latitude  longitude
# 0   40.727938 -73.985755
# 1   40.763365 -73.981489
# 2   40.780529 -73.952579
# 3   40.741764 -74.000419
# 4   40.759684 -73.968458
# 5   40.780904 -73.980348
# 6   40.716650 -73.993286
# 7   40.761009 -73.989868
# 8   40.753132 -73.976484
# 9   40.796840 -73.969529
# 10  40.709842 -74.008369
# 11  40.752614 -73.995855
# 12  40.769835 -73.959056
# 13  40.726523 -73.997593
# 14  40.741016 -73.988941
# 15  40.750641 -73.987218

# %%
df.to_csv('coordinates_stores.csv', index=False)
