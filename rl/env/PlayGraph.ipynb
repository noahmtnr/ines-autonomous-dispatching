# %%
from StreetGraph import StreetGraph
from Graphworld import Environment
from datetime import datetime
import random
import networkx as nx
import numpy as np
# %matplotlib inline

# %%
GRAPH_NAME = 'meinheim'
streetgraph = StreetGraph(GRAPH_NAME)
# start_hub = random.choice(list(streetgraph.graph.nodes()))
start_hub = 290333444
final_hub = random.choice(list(streetgraph.graph.nodes()))
if start_hub == final_hub: 
    final_hub = random.choice(list(streetgraph.graph.nodes()))

pickup_day = 1
pickup_hour =  np.random.randint(24)
pickup_minute = np.random.randint(60)
pickup_time=datetime(2022,1,pickup_day,pickup_hour,pickup_minute,0)


print("Start: ", start_hub)
print("Final: ", final_hub)
# Out:
# Start:  290333444
# Final:  309450344

# %%
g = streetgraph.graph.nodes(start_hub)
streetgraph.graph.nodes[start_hub]
# Out:
# {'y': 49.0133143, 'x': 10.7913339, 'street_count': 3}

# %%
env = Environment(streetgraph, start_hub, final_hub, pickup_time)

# %%
print(env.time)
print(env.availableActions())
print(env.position)
# Out:
# 2022-01-01 15:45:29.600000
# []
# 290333400

# %%
env.render(True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_59508b53180f4ae487a45a40568979bc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_59508b53180f4ae487a45a40568979bc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_59508b53180f4ae487a45a40568979bc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_59508b53180f4ae487a45a40568979bc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.025414419232796%2C%2010.807064260614125%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
env.step(1)
# Out:
# (290333400, -1, 3.6, False)

# %%
is_done = False
route_taken = []
cumulated_reward = 0
while(not is_done):
    for i in range(20):
        actions = env.availableActions()
        print("Length actions: ", len(actions))
        action = random.choice(range(len(actions)+1))
        position, reward, travel_time, is_done = env.step(action)
        print("Action taken: ", action)
        print("new position:", position)
        print("new time:", env.time)
        route_taken.append(position)
        cumulated_reward += reward

print("Package delivered after %s steps" %(len(route_taken)))
print("Reward: ", cumulated_reward)
# Out:
# Length actions:  0
# Action taken:  0
# new position: 354863048
# new time: 2022-01-01 17:53:44
# Length actions:  0
# Action taken:  0
# new position: 354863048
# new time: 2022-01-01 17:58:44
# Length actions:  0
# Action taken:  0
# new position: 354863048
# new time: 2022-01-01 18:03:44
# Length actions:  0
# Action taken:  0
# new position: 354863048
# new time: 2022-01-01 18:08:44
# Length actions:  2
# Action taken:  1
# new position: 290333400
# new time: 2022-01-01 18:17:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:22:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:27:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:32:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:37:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:42:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:47:54.200000
# Length actions:  0
# Action taken:  0
# new position: 290333400
# new time: 2022-01-01 18:52:54.200000
# Length actions:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb#ch0000009?line=6'>7</a> print("Length actions: ", len(actions))
#       <a href='vscode-notebook-cell:/Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb#ch0000009?line=7'>8</a> action = random.choice(range(len(actions)+1))
# ----> <a href='vscode-notebook-cell:/Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb#ch0000009?line=8'>9</a> position, reward, travel_time, is_done = env.step(action)
#      <a href='vscode-notebook-cell:/Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb#ch0000009?line=9'>10</a> print("Action taken: ", action)
#      <a href='vscode-notebook-cell:/Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/PlayGraph.ipynb#ch0000009?line=10'>11</a> print("new position:", position)
#
# File ~/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py:52, in Environment.step(self, action)
#      <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=48'>49</a> availableActions = self.availableActions()
#      <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=49'>50</a> step_duration = 0
# ---> <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=51'>52</a> if self.validateAction(action):
#      <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=52'>53</a>     if(action == 0):
#      <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=53'>54</a>         step_duration = 300
#
# File ~/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py:130, in Environment.validateAction(self, action)
#     <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=128'>129</a> def validateAction(self, action):
# --> <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=129'>130</a>     return action < len(self.availableTrips()) + 1
#
# File ~/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py:115, in Environment.availableTrips(self)
#     <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=112'>113</a> dict = grid['node_timestamps'][index]
#     <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=113'>114</a> for tupel_position in dict:
# --> <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=114'>115</a>     position_timestamp= datetime.strptime(str(dict[tupel_position]), "%Y-%m-%d %H:%M:%S")
#     <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=115'>116</a>     inTimeframe = start_timestamp <= position_timestamp and end_timestamp >= position_timestamp
#     <a href='file:///Users/n.mautnersprinteins.com/Documents/uni/ines-autonomous-dispatching/rl/env/Graphworld.py?line=116'>117</a>     startsInCurrentPosition = str(tupel_position) == position_str
#
# KeyboardInterrupt:
