# %%
import sys
sys.path.insert(0,"")

from StreetGraph import StreetGraph
from ManhattenGraph import ManhattenGraph
#from gym_graphenv.envs.Graphworld import GraphEnv

# %%
graph_meinheim = StreetGraph('meinheim', num_trips=4000, fin_hub=2, num_hubs=5)
graph_meinheim_trips = graph_meinheim.trips
print(graph_meinheim_trips)
# Out:
#       tripid  pickup_node  dropoff_node  pickup_day  pickup_hour  \
# 0          0    307664242     290333858           1           13
# 1          1    280324485     306225115           1            9
# 2          2    306221807     291556214           1            1
# 3          3    306221765     307662889           1            4
# 4          4    309441562     354863048           1            7
# ...      ...          ...           ...         ...          ...
# 3995    3995    306225115     309450366           1            2
# 3996    3996    307662889     306219024           1           12
# 3997    3997    280324491     290333400           1            3
# 3998    3998    309450340     306219024           1           21
# 3999    3999    307661801     309450229           1           15
#
#       pickup_minute     pickup_datetime  \
# 0                 2 2022-01-01 13:02:00
# 1                43 2022-01-01 09:43:00
# 2                34 2022-01-01 01:34:00
# ...

# %%
graph_manhatten = ManhattenGraph('small_manhattan',num_hubs=5)
graph_manhatten_trips = graph_manhatten.trips
print(graph_manhatten_trips)
# Out:
#       Unnamed: 0.1  Unnamed: 0         id  vendor_id      pickup_datetime  \
# 0                0           0  id2875421          2  2016-03-14 17:24:55
# 1                1           1  id2377394          1  2016-06-12 00:43:35
# 2                2           2  id3858529          2  2016-01-19 11:35:24
# 3                3           3  id3504673          2  2016-04-06 19:32:31
# 4                4           4  id2181028          2  2016-03-26 13:30:55
# ...            ...         ...        ...        ...                  ...
# 4978          4995        4995  id0956600          1  2016-02-12 19:07:51
# 4979          4996        4996  id0927465          2  2016-05-31 23:26:59
# 4980          4997        4997  id0112343          2  2016-03-17 22:51:22
# 4981          4998        4998  id1869452          2  2016-03-16 09:17:20
# 4982          4999        4999  id2617136          1  2016-01-13 22:33:34
#
#          dropoff_datetime  passenger_count  pickup_longitude  pickup_latitude  \
# ...
