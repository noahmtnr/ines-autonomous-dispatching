# %%
import gym

# %%
env = gym.make('CartPole-v1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13116/452875541.py in <module>
# ----> 1 env = gym.make('CartPole-v1')
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     674 # fmt: on
#     675 def make(id: str, **kwargs) -> "Env":
# --> 676     return registry.make(id, **kwargs)
#     677
#     678
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py in make(self, path, **kwargs)
#     518         spec = self.spec(path)
#     519         # Construct the environment
# --> 520         return spec.make(**kwargs)
#     521
#     522     def all(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py in make(self, **kwargs)
#     137             env = self.entry_point(**_kwargs)
#     138         else:
# --> 139             cls = load(self.entry_point)
#     140             env = cls(**_kwargs)
#     141
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py in load(name)
#      53 def load(name: str) -> Type:
#      54     mod_name, attr_name = name.split(":")
# ---> 55     mod = importlib.import_module(mod_name)
#      56     fn = getattr(mod, attr_name)
#      57     return fn
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\classic_control\__init__.py in <module>
# ----> 1 from gym.envs.classic_control.cartpole import CartPoleEnv
#       2 from gym.envs.classic_control.mountain_car import MountainCarEnv
#       3 from gym.envs.classic_control.continuous_mountain_car import Continuous_MountainCarEnv
#       4 from gym.envs.classic_control.pendulum import PendulumEnv
#       5 from gym.envs.classic_control.acrobot import AcrobotEnv
#
# ~\AppData\Roaming\Python\Python39\site-packages\gym\envs\classic_control\cartpole.py in <module>
#       8
#       9 import numpy as np
# ---> 10 import pygame
#      11 from pygame import gfxdraw
#      12
#
# ModuleNotFoundError: No module named 'pygame'

# %%
# Configure the algorithm.
config = {
    # Environment (RLlib understands openAI gym registered strings).
    "env": "Taxi-v3",
    # Use 2 environment workers (aka "rollout workers") that parallelly
    # collect samples from their own environment clone(s).
    "num_workers": 2,
    # Change this to "framework: torch", if you are using PyTorch.
    # Also, use "framework: tf2" for tf2.x eager execution.
    "framework": "torch",
    # Tweak the default model provided automatically by RLlib,
    # given the environment's observation- and action spaces.
    "model": {
        "fcnet_hiddens": [64, 64],
        "fcnet_activation": "relu",
    },
    # Set up a separate evaluation worker set for the
    # `trainer.evaluate()` call after training (see below).
    "evaluation_num_workers": 1,
    # Only for evaluation runs, render the env.
    "evaluation_config": {
        "render_env": True,
    }
}

# %%
# Create our RLlib Trainer.
trainer = PPOTrainer(config=config)
# Out:
# 2022-02-23 14:35:21,317	WARNING trainer.py:2279 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Trainer.train()`. Instead, you will have to call `Trainer.evaluate()` manually in order to trigger an evaluation run.
#  pid=21920) C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:729: UserWarning: WARN: Could not find module 'C:\Users\kirch\anaconda3\envs\osmnx\lib\site-packages\atari_py\ale_interface\ale_c.dll' (or one of its dependencies). Try using the full path with constructor syntax.
#  pid=21920)   logger.warn(str(e))
#  pid=21092) C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\envs\registration.py:729: UserWarning: WARN: Could not find module 'C:\Users\kirch\anaconda3\envs\osmnx\lib\site-packages\atari_py\ale_interface\ale_c.dll' (or one of its dependencies). Try using the full path with constructor syntax.
#  pid=21092)   logger.warn(str(e))
#  pid=21920) 2022-02-23 14:35:22,575	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\agents\trainer.py:811, in Trainer.setup(self, config)
#     810 try:
# --> 811     self._init(self.config, self.env_creator)
#     812 # New design: Override `Trainable.setup()` (as indented by Trainable)
#     813 # and do or don't call super().setup() from within your override.
#     814 # By default, `super().setup()` will create both worker sets:
#    (...)
#     817 # parallel to training.
#     818 # TODO: Deprecate `_init()` and remove this try/except block.
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\agents\trainer.py:923, in Trainer._init(self, config, env_creator)
#     921 def _init(self, config: TrainerConfigDict,
#     922           env_creator: Callable[[EnvContext], EnvType]) -> None:
# --> 923     raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# RayActorError                             Traceback (most recent call last)
# Input In [9], in <module>
#       1 # Create our RLlib Trainer.
# ----> 2 trainer = PPOTrainer(config=config)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\agents\trainer.py:728, in Trainer.__init__(self, config, env, logger_creator, remote_checkpoint_dir, sync_function_tpl)
#     725 self.evaluation_workers = None
#     726 self.evaluation_metrics = {}
# --> 728 super().__init__(config, logger_creator, remote_checkpoint_dir,
#     729                  sync_function_tpl)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\tune\trainable.py:122, in Trainable.__init__(self, config, logger_creator, remote_checkpoint_dir, sync_function_tpl)
#     120 start_time = time.time()
#     121 self._local_ip = self.get_current_ip()
# --> 122 self.setup(copy.deepcopy(self.config))
#     123 setup_time = time.time() - start_time
#     124 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\agents\trainer.py:826, in Trainer.setup(self, config)
#     812 # New design: Override `Trainable.setup()` (as indented by Trainable)
#     813 # and do or don't call super().setup() from within your override.
#     814 # By default, `super().setup()` will create both worker sets:
#    (...)
#     817 # parallel to training.
#     818 # TODO: Deprecate `_init()` and remove this try/except block.
#     819 except NotImplementedError:
#     820     # Only if user did not override `_init()`:
#     821     # - Create rollout workers here automatically.
#    (...)
#     824     # This matches the behavior of using `build_trainer()`, which
#     825     # should no longer be used.
# --> 826     self.workers = self._make_workers(
#     827         env_creator=self.env_creator,
#     828         validate_env=self.validate_env,
#     829         policy_class=self.get_default_policy_class(self.config),
#     830         config=self.config,
#     831         num_workers=self.config["num_workers"])
#     833     # Function defining one single training iteration's behavior.
#     834     if self.config["_disable_execution_plan_api"]:
#     835         # Ensure remote workers are initially in sync with the
#     836         # local worker.
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\agents\trainer.py:1925, in Trainer._make_workers(self, env_creator, validate_env, policy_class, config, num_workers, local_worker)
#    1889 @DeveloperAPI
#    1890 def _make_workers(
#    1891         self,
#    (...)
#    1898         local_worker: bool = True,
#    1899 ) -> WorkerSet:
#    1900     """Default factory method for a WorkerSet running under this Trainer.
#    1901
#    1902     Override this method by passing a custom `make_workers` into
#    (...)
#    1923         The created WorkerSet.
#    1924     """
# -> 1925     return WorkerSet(
#    1926         env_creator=env_creator,
#    1927         validate_env=validate_env,
#    1928         policy_class=policy_class,
#    1929         trainer_config=config,
#    1930         num_workers=num_workers,
#    1931         local_worker=local_worker,
#    1932         logdir=self.logdir,
#    1933     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py:100, in WorkerSet.__init__(self, env_creator, validate_env, policy_class, trainer_config, num_workers, local_worker, logdir, _setup)
#      92 # Create a local worker, if needed.
#      93 # If num_workers > 0 and we don't have an env on the local worker,
#      94 # get the observation- and action spaces for each policy from
#      95 # the first remote worker (which does have an env).
#      96 if local_worker and self._remote_workers and \
#      97         not trainer_config.get("create_env_on_driver") and \
#      98         (not trainer_config.get("observation_space") or
#      99          not trainer_config.get("action_space")):
# --> 100     remote_spaces = ray.get(self.remote_workers(
#     101     )[0].foreach_policy.remote(
#     102         lambda p, pid: (pid, p.observation_space, p.action_space)))
#     103     spaces = {
#     104         e[0]: (getattr(e[1], "original_space", e[1]), e[2])
#     105         for e in remote_spaces
#     106     }
#     107     # Try to add the actual env's obs/action spaces.
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ray\worker.py:1735, in get(object_refs, timeout)
#    1733             raise value.as_instanceof_cause()
#    1734         else:
# -> 1735             raise value
#    1737 if is_individual_id:
#    1738     values = values[0]
#
# RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=21092, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 598, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 452, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
# traceback: Traceback (most recent call last):
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#     from ray.rllib.env.base_env import BaseEnv
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#     from ray.rllib.env.base_env import BaseEnv
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#     import gym
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#     from gym import wrappers
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#     class NormalizeObservation(gym.core.Wrapper):
# AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,584	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,591	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,598	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,605	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092) 2022-02-23 14:35:22,579	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,587	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,594	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,602	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,608	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,612	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) 2022-02-23 14:35:22,615	ERROR worker.py:432 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=21920, ip=127.0.0.1)
#  pid=21920)   File "python\ray\_raylet.pyx", line 598, in ray._raylet.execute_task
#  pid=21920)   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#  pid=21920)   File "python\ray\_raylet.pyx", line 452, in ray._raylet.raise_if_dependency_failed
#  pid=21920) ray.exceptions.RaySystemError: System error: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21920) traceback: Traceback (most recent call last):
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21920)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21920)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21920)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21920)     obj = pickle.loads(in_band)
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21920)     from ray.rllib.env.base_env import BaseEnv
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21920)     import gym
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21920)     from gym import wrappers
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21920)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21920)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21920)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21920) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,615	ERROR serialization.py:289 -- partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) 2022-02-23 14:35:22,619	ERROR worker.py:432 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=21092, ip=127.0.0.1)
#  pid=21092)   File "python\ray\_raylet.pyx", line 598, in ray._raylet.execute_task
#  pid=21092)   File "python\ray\_raylet.pyx", line 620, in ray._raylet.execute_task
#  pid=21092)   File "python\ray\_raylet.pyx", line 452, in ray._raylet.raise_if_dependency_failed
#  pid=21092) ray.exceptions.RaySystemError: System error: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)
#  pid=21092) traceback: Traceback (most recent call last):
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 287, in deserialize_objects
#  pid=21092)     obj = self._deserialize_object(data, metadata, object_ref)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 194, in _deserialize_object
#  pid=21092)     return self._deserialize_msgpack_data(data, metadata_fields)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 172, in _deserialize_msgpack_data
#  pid=21092)     python_objects = self._deserialize_pickle5_data(pickle5_data)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\serialization.py", line 162, in _deserialize_pickle5_data
#  pid=21092)     obj = pickle.loads(in_band)
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\__init__.py", line 5, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\__init__.py", line 1, in <module>
#  pid=21092)     from ray.rllib.env.base_env import BaseEnv
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\ray\rllib\env\base_env.py", line 5, in <module>
#  pid=21092)     import gym
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\__init__.py", line 15, in <module>
#  pid=21092)     from gym import wrappers
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\__init__.py", line 17, in <module>
#  pid=21092)     from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#  pid=21092)   File "C:\Users\kirch\AppData\Roaming\Python\Python39\site-packages\gym\wrappers\normalize.py", line 43, in <module>
#  pid=21092)     class NormalizeObservation(gym.core.Wrapper):
#  pid=21092) AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)

# %%
# Run it for n training iterations. A training iteration includes
# parallel sample collection by the environment workers as well as
# loss calculation on the collected batch and a model update.
for _ in range(3):
    print(trainer.train())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <module>
#       1 # Run it for n training iterations. A training iteration includes
#       2 # parallel sample collection by the environment workers as well as
#       3 # loss calculation on the collected batch and a model update.
#       4 for _ in range(3):
# ----> 5     print(trainer.train())
#
# NameError: name 'trainer' is not defined
